# %% [markdown]
# <h1>In this notebook we querry github using github api in order to find repositories which contain Ansible
# files.</h1>

# %% [markdown]
# <p>More specifically we are going to use the <strong><i>search_files</i></strong> and <strong><i>search_repositories</i></strong> methods from the Github API in order to find Ansible repositories.</p><p>For the <i>search_files</i> method we construct a querry in order to find Ansible .yml and .yaml files. We run for each case twice the method since after some days of testing we noticed that the results are not identical.</p><p>For the <i>search_repositories</i> given a list of relevant keywords we search for repositories accordingly.</p><p>All repository results are saved in a list and we make sure for every list each item is unique. The final lists are 3 in total:</p>
#     <ul>
#         <li>A list containing repository results given the <strong><i>.yml</i></strong> file search</li>
#         <li>A list containing repository results given the <strong><i>.yaml</i></strong> file search</li>
#         <li>A list containing repository results given relative keywords regarding ansible</li>
#     </ul>
#    <p>The 3 final lists are saved in pickle files.</p>

# %%
import os, os.path
from github import Github
import csv
import pandas as pd
import pickle

# %%
ACCESS_TOKEN = '6891e3c18d2f0e182cc0903e3511a5af7c030ba4'
g = Github(ACCESS_TOKEN)
rate_limit = g.get_rate_limit()
rem = rate_limit.core
print(rem.remaining,'\n',rate_limit,'\n',rate_limit.search)
# Out:
# 4578
#  RateLimit(core=Rate(remaining=4578, limit=5000))
#  Rate(remaining=30, limit=30)

# %%
repo_list = []

# %%
def add_repos_to_list(result):
    
    reps_list = []
    
    for res in result:
        reps_list = res.repository.full_name
        
    return reps_list

# %%
def download_gitfile(file, download_path):
    
    file_url = file.download_url        
    filename = file_url.rsplit('/', 1)[1]
    final_path = download_path+filename
        
    #rename file if exists already
    if os.path.isfile(final_path):
        temp = os.path.splitext(final_path)
        final_path = temp[0]+str(count)+temp[1]
        #final_path = final_path+str(count)        
    
    print(final_path,file.repository)

    line = f'{line_num})filename: {final_path}, respository:{file.repository}\n'
    appendFile = open('exampleFile.txt','a')
    appendFile.write(line)
    appendFile.close()
        
    r = requests.get(file.download_url)
        
    with open(final_path, 'wb') as f:
        f.write(r.content)

# %%
def search_github(keyword,file_type):
    
    count = 0
    line_num = 1 
    #check call limit
    rate_limit = g.get_rate_limit()
    rate = rate_limit.search
    if rate.remaining == 0:
        print(f'You have 0/{rate.limit} API calls remaining. Reset time: {rate.reset}')
        return
    else:
        print(f'You have {rate.remaining}/{rate.limit} API calls remaining')
    
    #construct querry
    query = f'{keyword} in:file extension:{file_type} filename: NOT ".travis" repo: NOT "ansible/ansible"'
    result = g.search_code(query, order='desc')
    
    return result

# %%
result = search_github('ansible','yml')
rep_list = []
for res in result:
    print(res.repository.full_name)
# Out:
# You have 30/30 API calls remaining
# markokole/iac-aws-hadoop
# aolwas/ansible-playbooks
# yangwang166/hwx_ansible
# hubakias/ansible
# ekapusta/docker-ansibled-centos
# fabricioboreli/ansible-role-mariadb
# asifkhan7000/ansible-hortonworks
# foxutech/wazuh-ansible
# pacificbreeze007/DevOps
# farhana-khan/ansible-hortonworks
# Thulium-Drake/ansible-role-apt
# banna2019/devops-project
# caseyrichins/ansible-paranoid
# myprojectphoenix/HDPonAWSwithANSIBLE
# gridgentoo/ansible-hortonworks
# fanttazio/AWX_Test
# patalwell/hdp-ansible
# foxutech/wazuh-ansible
# zackmeso/ansible-kerberized-hw-cluster
# arunkumarmurugesan/anisble
# Misk77/examApp
# venkey1185/ansible-hdf
# vishwas-devops/Assignments
# rinnerr/openio-rawx
# open-io/ansible-role-openio-repository
# robertshell22/d8-thunder-vm
# softasap/sa-python
# banna2019/study-package
# opendevshop/devshop
# softasap/sa-docker
# opendevshop/devshop
# z1odeypnd/ansible-demo-00
# NLNOG/ring-ansible
# stevestrutt/roleclone
# ...

# %%
repos_yml = ['markokole/iac-aws-hadoop',
'yangwang166/hwx_ansible',
'hubakias/ansible',
'ekapusta/docker-ansibled-centos',
'aolwas/ansible-playbooks',
'fabricioboreli/ansible-role-mariadb',
'asifkhan7000/ansible-hortonworks',
'foxutech/wazuh-ansible',
'pacificbreeze007/DevOps',
'farhana-khan/ansible-hortonworks',
'arunkumarmurugesan/anisble',
'Thulium-Drake/ansible-role-apt',
'myprojectphoenix/HDPonAWSwithANSIBLE',
'caseyrichins/ansible-paranoid',
'banna2019/devops-project',
'gridgentoo/ansible-hortonworks',
'alikins/strawman_mazer_shelf',
'robertshell22/d8-thunder-vm',
'vikramjanarthanan/ansible-hortonworks',
'Misk77/examApp',
'patalwell/hdp-ansible',
'foxutech/wazuh-ansible',
'rinnerr/openio-rawx',
'open-io/ansible-role-openio-repository',
'softasap/sa-docker',
'renanmfd/smartbet',
'MonkiiBuilt/code-test-drupal',
'venkey1185/ansible-hdf',
'vishwas-devops/Assignments',
'brianannis/ubuntu-bootstrap',
'andrewfandrew/horsepower',
'tenhishadow/salt_minion',
'opendevshop/devshop',
'NLNOG/ring-ansible',
'softasap/sa-python',
'adamkingit/bluemix-openstack-deploy',
'stevestrutt/roleclone',
'che607/test_1',
'banna2019/study-package',
'fordse3/Samedits',
'sivavadivel/ansible_hwx_model',
'chris-greatens/drupal-magento',
'GluuFederation/acceptance-tests',
'yangwang166/hwx_ansible',
'Jason-Jongjin-Lim/ocp_hosts_references',
'softasap/sa-uwsgi',
'JugglerX/drydock',
'softasap/sa-postgres-workplace',
'markokole/iac-aws-hadoop',
'BriceMichalski/tp-devops-ansible',
'darkwizard242/ansible-role-docker',
'flashashen/zombiepoetryproject',
'silbermantel/all_my_hosts',
'oops-to-devops/mysql_box',
'shelleg/ansible-role-rabbitmq',
'nephelaiio/ansible-role-elastic-repo',
'gsteinhoff/ut-first-test',
'openstack/openstack-ansible-rabbitmq_server',
'rinnerr/openio-rawx',
'M4XW3L-8/ansible-workstation',
'banna2019/devops-project',
'IBMCloudDevOps/travis-openstack-deploy',
'M4XW3L-8/ansible-workstation',
'c-po/ansible-role-unifi',
'coetzeer/ansible-seedbox',
'elevatedthird/nyc-books-api-professional-development',
'JefMuller/ansible',
'owlick/TOSHIBA',
'd1netreus/wazuh-ansible',
'hortonworks/ansible-hortonworks',
'o-saddane/drupal-vm',
'geerlingguy/ansible-role-php-versions',
'egarat/ansible-demo',
'fotuzlab/dvvm',
'alexburrows/commerceauction',
'sborenst/simple_agnostic_deployer',
'shakeme/localkube',
'pacificbreeze007/DevOps',
'luk82/drupal-vm-template',
'cdelgehier/ansible-role-openio-sds',
'open-io/ansible-role-openio-repository',
'SoftStackFactory/ssf-devops',
'oops-to-devops/traefik_box',
'softasap/sa-box-awx',
'p-avery/wazuh',
'banna2019/devops-project',
'qngo-windwalker/opigno',
'jmpantoja/origami',
'asifkhan7000/ansible-hortonworks',
'DipakShrestha18/corporate-d8-react',
'darkwizard242/ansible-role-docker',
'darkwizard242/ansible-role-docker',
'liujun1990/ansible-k8s-tls',
'liujun1990/ansible-k8s-tls',
'kimblev/bar3911',
'cactus-blossom-it-services-limited/bulldog',
'theonlydoo/configz',
'faisalzafaruae/ansible-hortonworks',
't324inc/d324-vm',
'IBMCloudDevOps/bluemix-openstack-deploy',
'liujun1990/ansible-k8s-tls',
'liujun1990/ansible-k8s-tls',
'dantin/HDP-Ansible',
'plamen-penev-ffw/shaolin',
'fayaaz/spacewalk.ansible',
'jwflory/rit-nssa-320-infrastructure',
'banna2019/study-package',
'GieronAdam/edu-drupal',
'pacificbreeze007/devops_yard',
'kevit/overlay',
'kevit/overlay',
'cactus-blossom-it-services-limited/baudelaire',
'redhat-cop/containers-quickstarts',
'farhana-khan/ansible-hortonworks',
'buldug/dugsite',
'vinous22/MoviesProject',
'nasa9084/ansible_playbooks',
'vicenteg/mapr-repo-mirror',
'aka-cafu/ansible',
'gmauro/ansible-ice',
'chauanhtuandl/ansible-role-php-versions',
'ByronGary/DrupalVMPort',
'smutek/drupal-cookbook',
'Zuiev/yca',
'rayhanur-rahman/CSC503-Project',
'andrelohmann/ansible-role-gitlab',
'softasap/sa-sentry',
'Marie-L/NewsLanding',
'Brigette-Eckert/drupal-vm-playground',
'gridgentoo/ansible-hortonworks',
'brettsaguid/iconics-site',
'buldug/dugsite',
'JackyChenNgu/tripleo-quickstart',
'itlongtruong/Do-Exercise-1',
'andrewadcock/cookbook-second-edition',
'jmpantoja/origami',
'maxxko/segment.nginx',
'banna2019/study-package',
'banna2019/study-package',
'masumndc1/lxd-cluster',
'willpllc/infra-homework',
'pacificbreeze007/devops_yard',
'markokole/iac-aws-hadoop',
'sjtug/kxsw',
'softasap/sa-mysql',
'nfaction/ansible-bootstrap',
'echo15/lcctest',
'nasa9084/ansible_playbooks',
'BYU-PCCL/provisioning',
'cristiroma/bioland',
'andrewadcock/d8-basic-blog',
'Provizanta/ansible-role-clang',
'skpatterson/openshift_advanced_deployment',
'suma-project/Suma-Vagrant',
'rcbops/openstack-ops',
'kube-bare/kube-bare',
'lgaggini/ansible-rspamd',
'itlongtruong/configure-ansible',
'kimblev/md8',
'asifkhan7000/ansible-hortonworks',
'phcaguiar/infra-financial-products-tribe-common-vsts-agents',
'SpivEgin/roles',
'benjamin-smith/ansible-ondrej-php-repo',
'sivavadivel/ansible_hwx_model',
'dragos-dumi/mysite-artifact',
'vikramjanarthanan/ansible-hortonworks',
'muym-chs/drupal8vm-apache',
'ryanhhtan/my-ansible-roles',
'stdin/ansible-freeswitch',
'openstack/tripleo-quickstart',
'AnotherKamila/bsdops',
'dj-wasabi/ansible-ossec-server',
'NYULibraries/mediacommons-vm',
'hieuvecto/demo3boxes',
'evanhsu/ansible-shared-host',
'MinistryOfJusticeCZ/ansible-linuxdvz',
'uchida/ansible-role-nvidia-repo',
'evgenia-tkachenko/drupal_events',
'zx1986/phpday-ansible',
'wazuh/wazuh-ansible',
'AnotherKamila/bsdops',
'Fluxusio/vm-winnergroup',
'jonnymac15/movieproject',
'JackyChenNgu/tripleo-quickstart',
'jonnymac15/jonsrecipes',
'coulonpascal/homeserver',
'galaxyproject/ansible-cvmfs',
'amclaurin/ansible-workstation',
'purerosefallen/playbooks',
'andrewadcock/d8-basic-blog',
'skpatterson/openshift_advanced_deployment',
'suma-project/Suma-Vagrant',
'Provizanta/ansible-role-clang',
'rcbops/openstack-ops',
'andrelohmann/ansible-role-mongodb',
'sebedh/ansible_school',
'jucarre/Ansible-test',
'kube-bare/kube-bare',
'lgaggini/ansible-rspamd',
'itlongtruong/configure-ansible',
'kimblev/md8',
'asifkhan7000/ansible-hortonworks',
'phcaguiar/infra-financial-products-tribe-common-vsts-agents',
'benjamin-smith/ansible-ondrej-php-repo',
'SpivEgin/roles',
'sivavadivel/ansible_hwx_model',
'dragos-dumi/mysite-artifact',
'ryanhhtan/my-ansible-roles',
'mugoweb/mugo_base_boxes',
'mugoweb/mugo_base_boxes',
'vikramjanarthanan/ansible-hortonworks',
'muym-chs/drupal8vm-apache',
'DataDog/ansible-datadog',
'ryanhhtan/my-ansible-roles',
'stdin/ansible-freeswitch',
'openstack/tripleo-quickstart',
'AnotherKamila/bsdops',
'rayhanur-rahman/CSC503-Project',
'dj-wasabi/ansible-ossec-server',
'NYULibraries/mediacommons-vm',
'hieuvecto/demo3boxes',
'evanhsu/ansible-shared-host',
'MinistryOfJusticeCZ/ansible-linuxdvz',
'uchida/ansible-role-nvidia-repo',
'evgenia-tkachenko/drupal_events',
'zx1986/phpday-ansible',
'evalero/ansible-atom',
'wazuh/wazuh-ansible',
'yuyicai/kubernetes-ha-ansible',
'DistributedSystemsGroup/sysadmin-dsp',
'bhcleek/ansible-playbooks',
'thepg/Ansible-HW-kerberized',
'pawankkamboj/kubernetes-ansible',
'masumndc1/lxd-cluster',
'nikaro/ansible-role-nginx',
'MaxBab/bareos-ansible',
'blurblah/ansible-role-mesos-slave',
'LEARNAcademy/devpass-devops',
'mhalano/ansible-role-atom',
'blurblah/ansible-role-mesos-master',
'mrleerkotte/ansible-role-unifi',
'Malek23923/bef',
'skipidar/Vagrant_Templates',
'skipidar/Vagrant_Templates',
'ju2wheels/ansible-galaxy-ju2wheels.pyenv',
'jaredledvina/sensu-go-ansible',
'mmolinac/LinuxToolset',
'sloppycoder/linux-dev-ansible',
'mrgloba/ansible-asterisk-freepbx',
'rayhanur-rahman/CSC503-Project',
'rayhanur-rahman/CSC503-Project',
'rohanraja/codevine',
'openstack/tripleo-quickstart',
'openstack/tripleo-quickstart',
'M4XW3L-8/ansible-workstation',
'blurblah/ansible-role-mesos-slave',
'varshineevenkatesan/ambari_with_flink',
'newstar123/VM---master',
'nikaro/ansible-role-nginx',
'dom18fr/sudradiobox',
'oscpe262/ansible-role-cockpit',
'MiguelJulia/GCC2019_GalaxyAnsibleDeplyoment_CVMFS',
'wellcometrust/upd',
'DevOps-Testing/AnsibleController',
'Shahriar567/Spark-Hadoop_ClusterSetup',
'Shahriar567/Spark-Hadoop_ClusterSetup',
'openstack/tripleo-quickstart',
'nfaction/ansible-bootstrap',
'OpenNebula/addon-host-provision',
'kgatjens/d8_vm_vagrant',
'OpenNebula/addon-host-provision',
'phcaguiar/infra-financial-products-tribe-common-vsts-agents',
'SpivEgin/roles',
'camstorrs/stripe-drupal',
'laurentedel/ansible-hdp',
'pugna0/ansible',
'egarat/ansible-demo',
'sajjadwasim/test2',
'devopspoc-ram/sensu',
'devopspoc-ram/sensu',
'VladimirChudovskiy/learn_drupalvm',
'belbassy/spacefed',
'MrLokans/raspberry-pi-playbooks',
'pajavyskocil/elk_test',
'cmihai-ansible/flatpak',
'cmihai-ansible/virtualbox',
'tenhishadow/pve_on_debian',
'ceyounger/digitalocean',
'krzysztof-ksiazek/cc-k8s',
'wakwanza/ansible-role-arangodb',
'hensing/dotfiles',
'andrelohmann/ansible-role-gitlab_docker_runner',
'geerlingguy/drupal-vm',
'mechaphish/setup',
'brad-x/ansible-sysadmin',
'andrewwh/ansible-workstation',
'faisalzafaruae/ansible-hortonworks',
'softasap/sa-docker',
'M4XW3L-8/ansible-workstation',
'spolex/hwk-ansible',
'rlex/ansible-role-influxdb',
'Provizanta/ansible-role-beats',
'fititnt/ap-application-load-balancer',
'pacificbreeze007/devops_yard',
'toddstoffel/cdc_demo',
'open-io/ansible-role-openio-sds',
'CreatorDev/DeviceServer',
'hashnfv/hashnfv-qtip',
'phpguy84/ed-t1',
'R4scal/home-lab',
'ceyounger/ansible',
'vikramjanarthanan/ansible-hortonworks',
'softasap/sa-chatops-errbot',
'darkwizard242/ansible-role-azurecli',
'hortonworks/ansible-hortonworks',
'jaredledvina/sensu-go-ansible',
'galexrt/ansible-cockpit',
'SpaceHotDog/scriptsDB',
'joshbenner/ansible-role-sensu',
'sukujgrg/kubernetes-do-ansible',
'18414/kubernetes-setup',
'rayhanur-rahman/CSC503-Project',
'usegalaxy-eu/infrastructure-playbook',
'sivavadivel/ansible_hwx_model',
'Provizanta/ansible-role-elasticsearch',
'MaxBab/bareos-ansible',
'dokuhebi/home_config',
'dokuhebi/home_config',
'testjatin93/ansible3',
'alikins/strawman_mazer_shelf',
'alikins/strawman_mazer_shelf',
'MaxBab/bareos-ansible',
'hortonworks/ansible-hortonworks',
'eellak/ansible',
'sangrealest/ansible-playbooks',
'mattiast/dotfiles',
'liwonace/lpms',
'hashnfv/hashnfv-qtip',
'netbootxyz/netboot.xyz',
'gaelL/molecule-test',
'lquessenberry/scaling-octo-enigma',
'piotrkpc/tripleo-quickstart-configs',
'deceptionlogic/ansible-deception-agent',
'thingsym/vaw',
'thingsym/vaw',
'thingsym/vaw',
'morganllj/ansible-playbooks',
'h0ke/vagrant-python-dev',
'thingsym/vap',
'thingsym/vap',
'thingsym/vap',
'usegalaxy-eu/vgcn',
'fxlv/ansible',
'renanmfd/smartbet',
'renanmfd/smartbet',
'MonkiiBuilt/code-test-drupal',
'MonkiiBuilt/code-test-drupal',
'chris-greatens/drupal-magento',
'kevit/overlay',
'kevit/overlay',
'ITSvitCo/Datacharmer',
'nofuturekid/ansible',
'juttayaya/devops',
'fordse3/Samedits',
'jeffhung/ansible-kibana',
'd0pang/ansible-hdp3.1',
'piotrkpc/tripleo-quickstart-configs',
'riponbanik/ansible-role-foreman',
'alexblackie/bootstart',
'cmihai-ansible/jenkins',
'HugoPeters1024/config',
'thingsym/vaw',
'alikins/top_geerlingguy',
'usegalaxy-eu/jenkins-worker',
'cmihai-ansible/vscode',
'thingsym/vap',
'uw-dims/ansible-dims-playbooks',
'rayhanur-rahman/CSC503-Project',
'kaminek/playbooks',
'ernstp/ansible',
'tagliateller/urban-train',
'renanmfd/meninadasbalas',
'andrewfandrew/horsepower',
'andrewfandrew/horsepower',
'jan-warchol/ansible-workstation-setup',
'chrissnyder2337/symfony-ansible-starter-vm',
'tjeastman/ansible-playbooks',
'rlex/ansible-role-zabbix-agent',
'rayhanur-rahman/CSC503-Project',
'jeffhung/ansible-logstash',
'henderiw/ansible',
'cmihai-ansible/cookiecutter-role',
'UtrechtUniversity/yoda-ansible',
'honzamach/ansible-role-mentat-dev',
'kaminek/playbooks',
'ernstp/ansible',
'chrissnyder2337/symfony-ansible-starter-vm',
'egeneralov/timescaledb',
'Modulus/ansible-forman',
'che607/test_1',
'che607/test_1',
'DistributedSystemsGroup/sysadmin-dsp',
'JackyChenNgu/tripleo-quickstart',
'JackyChenNgu/tripleo-quickstart',
'marinoska/vagrant-ansible',
'deep-ty/ansible-docker-setup',
'deep-ty/ansible-docker-setup',
'gitclonparis/ansi',
'dceoy/ansible-dropbox',
'leiting920708/ansible',
'Feng-Shui/whitesite',
'rayhanur-rahman/CSC503-Project',
'HauptJ/Ansible-WordPress-CloudFlare',
'JackyChenNgu/tripleo-quickstart',
'kmane-mem/ansible',
'JugglerX/drydock',
'csm789/OMT-Ansible',
'marvinpinto/laptop',
'reyesg/vagrant',
'arunkumarmurugesan/anisble',
'flyhard/awsHashicorpStack',
'FinalDes/ansible-mongodb',
'equalitie/eqpress',
'softasap/sa-box-awx',
'rameshkalirawana/gra',
'Provizanta/ansible-role-logstash',
'owlick/TOSHIBA',
'owlick/TOSHIBA',
'Modulus/ansible-forman',
'aquarion/autopelago',
'egi-qc/ansible-umd',
'egormin/ansible_portable',
'seungkyua/my-kubespray',
'FinalDes/ansible-nginx',
'colinlabs/ansible-kube',
'filusATpsc/sdaia-xsede',
'billryan/ansible',
'JackyChenNgu/tripleo-quickstart',
'fotuzlab/dvvm',
'fotuzlab/dvvm',
'Lucas5Lucas/drupalpractice',
'uchida/ansible-role-nvidia-driver',
'alexburrows/commerceauction',
'openstack/openstack-ansible-ops',
'openstack/openstack-ansible-ops',
'nfaction/ansible-virtualbox',
'rayhanur-rahman/SLIC-Ansible',
'rayhanur-rahman/SLIC-Ansible',
'nCoda/ncoda',
'o-saddane/drupal-vm',
'rayhanur-rahman/SLIC-Ansible',
'rayhanur-rahman/SLIC-Ansible',
'nCoda/ncoda',
'o-saddane/drupal-vm',
'selwynpolit/drupal8dev1',
'saifullah-ali/ansible_dev',
'bix29/ast',
'full-ci-cd/ansible_repo',
'bossjones/boss-ansible-role-rsyslogd',
'devopsstore/ansible-sei',
'AnotherKamila/bsdops',
'varcodefix/stepik-webapp-infra',
'purerosefallen/playbooks',
'proacem/ansible.mariadb',
'rayhanur-rahman/CSC503-Project',
'Provizanta/ansible-role-nvidia-cuda',
'FinalDes/ansible-docker-ce',
'rmcveigh/base-drupalvm',
'kongyibjcn/cloud-infrastructure-setup',
'rayhanur-rahman/CSC503-Project',
'elias-neves93/lab-k8s',
'wakwanza/ansible-role-rethinkdb',
'DevoInc/ansible-keepalived',
'higgsmass/mpi-bprof',
'codeghar/ansible-roles',
'softasap/sa-vpn-pritunl',
'BriceMichalski/liv_lyon_provisionning',
'ansible/ansible-bare',
'openstack/tripleo-quickstart',
'sktelecom-oslab/taco-kubespray',
'GieronAdam/edu-drupal',
'GieronAdam/edu-drupal',
'tinproject/adalab-ubuntu',
'cmakerstudio/cmaker-gluster-client',
'Srinivasan18/icinganew2',
'Srinivasan18/icinganew2',
'codeghar/ubuntu-dev-box-with-ansible',
'ansible-collection-migration/notstdlib.moveitallout',
'jacek-jarosiewicz/ansible',
'usha-21/ansible',
'ByronGary/DrupalVMPort',
'smutek/drupal-cookbook',
'buldug/dugsite',
'xiebinming/ceph',
'brad-x/ansible-sysadmin',
'Zuiev/yca',
'Zuiev/yca',
'nguyentrung0904/ansible_centos_7',
'alikins/strawman_mazer_shelf',
'teatron/ansible',
'jj0cker/ansible-role-repo_bareos',
'alxgomz/ansible-alfbm',
'cristiroma/bioland',
'openstack/tripleo-quickstart',
'jxmsn/https-github.com-ansible-ansible',
'andrewadcock/cookbook-second-edition',
'ermolaev/ansible-ubuntu-desktop',
'ngetchell/ansible-powershell',
'Rajeshkumar90/Ansible',
'wilsonLima/setup-desktop-virt-linux',
'wulei1984/ansible',
'kant13/ansible',
'yanyao/newton-roles',
'uchida/ansible-role-docker',
'rayhanur-rahman/SLIC-Ansible',
'TEK-TELUGU-CHANNEL/Ansible',
'gebv/goapp_example',
'plamen-penev-ffw/shaolin',
'plamen-penev-ffw/shaolin',
'inuvika/ansible-ovd',
'freedbka/agents',
'yobupeddhi/ansible',
'JackyChenNgu/tripleo-quickstart',
'JackyChenNgu/tripleo-quickstart',
'insight-infrastructure/ansible-icon-prep',
'varshineevenkatesan/ambari_with_flink',
'cmihai-ansible/docker',
'jmpantoja/origami',
'jmpantoja/origami',
'hashy0917/ansible-study',
'lsantiago2004/acquia-training',
'hongsumfyp/owasp-ansible-bamboo',
'iqreateinfotech/ansible-all',
'DipakShrestha18/corporate-d8-react',
'DipakShrestha18/corporate-d8-react',
'ansible-collection-migration/ansible.community',
'shanedabes/.dotfiles',
'qngo-windwalker/opigno',
'qngo-windwalker/opigno',
'cloudsoftnew/ansiblelamp',
'Srinivasan18/icinganew2',
'reyesg/vagrant',
'codeghar/ubuntu-dev-box-with-ansible',
'ansible-collection-migration/notstdlib.moveitallout',
'jacek-jarosiewicz/ansible',
'mibexx/docker-for-testing',
'usha-21/ansible',
'ByronGary/DrupalVMPort',
'smutek/drupal-cookbook',
'buldug/dugsite',
'xiebinming/ceph',
'brad-x/ansible-sysadmin',
'Zuiev/yca',
'Zuiev/yca',
'nguyentrung0904/ansible_centos_7',
'alikins/strawman_mazer_shelf',
'teatron/ansible',
'jj0cker/ansible-role-repo_bareos',
'alxgomz/ansible-alfbm',
'cristiroma/bioland',
'openstack/tripleo-quickstart',
'jxmsn/https-github.com-ansible-ansible',
'andrewadcock/cookbook-second-edition',
'ermolaev/ansible-ubuntu-desktop',
'ngetchell/ansible-powershell',
'Rajeshkumar90/Ansible',
'wilsonLima/setup-desktop-virt-linux',
'tinproject/tinproject-files',
'tinproject/tinproject-files',
'tinproject/tinproject-files',
'darkwizard242/ansible-role-azurecli',
'xiebinming/ceph',
'brad-x/ansible-sysadmin',
'Zuiev/yca',
'Zuiev/yca',
'nguyentrung0904/ansible_centos_7',
'alikins/strawman_mazer_shelf',
'teatron/ansible',
'jj0cker/ansible-role-repo_bareos',
'Srikanthchowdhary/cloud-formation',
'alxgomz/ansible-alfbm',
'cristiroma/bioland',
'openstack/tripleo-quickstart',
'jxmsn/https-github.com-ansible-ansible',
'andrewadcock/cookbook-second-edition',
'ermolaev/ansible-ubuntu-desktop',
'ngetchell/ansible-powershell',
'Rajeshkumar90/Ansible',
'wilsonLima/setup-desktop-virt-linux',
'tinproject/tinproject-files',
'tinproject/tinproject-files',
'tinproject/tinproject-files',
'tinproject/tinproject-files',
'tinproject/tinproject-files',
'tinproject/tinproject-files',
'Vemulashiva/Ansible',
'darnik22/bamboo-kube',
'ansible-collection-migration/ansible-base',
'michMartineau/packer-jenkins',
'thepg/Ansible-HW-kerberized',
'NYULibraries/mediacommons-vm',
'NYULibraries/mediacommons-vm',
'thepg/Ansible-HW-kerberized',
'openstack/tripleo-quickstart',
'wilsonLima/setup-desktop-virt-linux',
'arun2908/prathyu',
'Gemmers0n/ansible',
'bwatsonsf/solr',
'pulibrary/ansible_actions_test',
'instantlinux/docker-tools',
'sajjadwasim/ansible-role-nvidia-driver',
'negiper/ansible',
'hardyoyo/ucdlfx19-serverspec-workshop',
'hardyoyo/ucdlfx19-serverspec-workshop',
'cactus-blossom-it-services-limited/baudelaire',
'cactus-blossom-it-services-limited/baudelaire',
'indigo-dc/ansible-role-indigo-repo',
'jonnymac15/movieproject',
'cactus-blossom-it-services-limited/bulldog',
'cactus-blossom-it-services-limited/bulldog',
'likg/ansible-role-apt-repo-sury-org',
'pwnall/igor',
'ocha/ansible-role-dotnet-core',
'not-a-rocket-scientist-yet/ansible-playbooks',
'Shridharbhandar/catalog',
'markokole/aws-terraform-hdp',
'karalov/ansible',
'michMartineau/packer-jenkins',
'rayhanur-rahman/SLIC-Ansible',
'vml-jbartlett/JB-DrupalVM',
'blyhank/DevOps',
'blyhank/DevOps',
'0x3bfc/Sitechain_paper_performanceAnalysis',
'MikiManor/DevOpsCourse-FinalProject',
'nicholasdille/dotfiles',
'lammensj/tfs',
'ceyounger/digitalocean',
'yzd-wiety/ansible-provider-docs',
't324inc/d324-vm',
't324inc/d324-vm',
'injectedMonkey/ansible-role-php-fpm',
'cpitre/ansible-role-jenkins',
'icmdb/ansible',
'M4XW3L-8/ansible-workstation',
'ading1977/ansible-ecp',
'mdimarino/vagrant',
'openstack/tripleo-quickstart',
'mvilain/ansible-common-role',
'Fluxusio/vm-winnergroup',
'philip-preston/ti_test',
'philip-preston/ti_test',
'jeanaps/jenkinslab',
'oudomsieng/mean-playbook',
'oudomsieng/mean-playbook',
'damacus/ansible-opsview-agent',
'OpenShiftInAction/autoinstaller',
'alexandrdnlv/DrupalVM-D8stable',
'darkwizard242/ansible-role-polychromatic',
'myprojectphoenix/HDPonAWSwithANSIBLE',
'nishan-pa/ansible-role-mysql5.7',
'philip-preston/ti_test',
'darkwizard242/ansible-role-polychromatic',
'alexandrdnlv/DrupalVM-D8stable',
'myprojectphoenix/HDPonAWSwithANSIBLE',
'dashpradeep99/Ansible',
'ericbaranowski/ansible',
'ecaepp/ansible_role_nginx',
'Brigette-Eckert/drupal-vm-playground',
'Brigette-Eckert/drupal-vm-playground',
'CioRodica/kickstart',
'CioRodica/kickstart',
'brettsaguid/iconics-site',
'brettsaguid/iconics-site',
'ALLOcloud/ansible-role-verdaccio',
'suriya91/pro_ans',
'gapple/cnibdemo',
'gapple/cnibdemo',
'UtrechtUniversity/yoda-ansible',
'nishan-pa/ansible-role-mysql5.7',
'insight-infrastructure/ansible-icon-prep',
'awsautomation/Ansible',
'liujun1990/ansible-k8s-tls',
'liujun1990/ansible-k8s-tls',
'jonnymac15/jonsrecipes',
'jonnymac15/movieproject',
'kanr/vagrant-ansible-unifi',
'aldunchev/drupal-json-api',
'aldunchev/drupal-json-api',
'rahulon001/Ansibel_PYTHON',
'alikins/strawman_mazer_shelf',
'ansible/ansible-examples']

# %%
print('The length is: {0}, and the unique lenght is {1}'.format(len(repos_yml),len(set(repos_yml))))
# Out:
# The length is: 691, and the unique lenght is 422

# %%
unique_repos_yml = set(repos_yml)
# unique_repos

# %%
result = search_github('ansible','yaml')
rep_list = []
for res in result:
    print(res.repository.full_name)
# Out:
# You have 17/30 API calls remaining
# alghanmi/my-debian-box
# jtyr/ansible-telegraf
# jeanfrancoisgratton/mainline
# Sebor/ansible
# evgeniy-novikov/zabbix-agent
# CumulusNetworks/citc-mesos-1
# rayhanur-rahman/CSC503-Project
# jtyr/ansible-prometheus
# vecin2/dotfiles
# FunTimeCoding/ansible-backports
# evgeniy-novikov/zabbix-agent
# hemidactylus/ostracion
# slegs/cgrates-docker
# xinghu0164/TouchFrame-Group
# xinghu0164/TouchFrame-Group
# xinghu0164/TouchFrame-Group
# agude/ansible
# Mirantis/ceph-lcm
# Shasthojoy/citc-openstack-1
# 9seconds/ansible-devbox
# xinghu0164/TouchFrame-Group
# jtyr/ansible-alertmanager
# xinghu0164/TouchFrame-Group
# cgrates/cgrates
# ilyakov/playing_with_ansible_innova
# dragon699/pg_upgrade
# AndresBott/ansible-autobott
# victorock/ansible-playground
# CumulusNetworks/citc-openstack-1
# BlaiseRitchie/dotfiles
# BlaiseRitchie/dotfiles
# davepanarese/ansible-varnish
# progamesigner/playbooks
# entercloudsuite/ansible-varnish
# ...

# %%
repos_yaml = ['alghanmi/my-debian-box',
'jtyr/ansible-telegraf',
'jeanfrancoisgratton/mainline',
'Sebor/ansible',
'CumulusNetworks/citc-mesos-1',
'evgeniy-novikov/zabbix-agent',
'rayhanur-rahman/CSC503-Project',
'paulbovbel/ansible-personal',
'jtyr/ansible-prometheus',
'vecin2/dotfiles',
'FunTimeCoding/ansible-backports',
'evgeniy-novikov/zabbix-agent',
'paulbovbel/ansible-personal',
'Mirantis/ceph-lcm',
'hemidactylus/ostracion',
'jtyr/ansible-alertmanager',
'slegs/cgrates-docker',
'xinghu0164/TouchFrame-Group',
'xinghu0164/TouchFrame-Group',
'xinghu0164/TouchFrame-Group',
'agude/ansible',
'Shasthojoy/citc-openstack-1',
'9seconds/ansible-devbox',
'xinghu0164/TouchFrame-Group',
'cgrates/cgrates',
'xinghu0164/TouchFrame-Group',
'ilyakov/playing_with_ansible_innova',
'usamacheema786/kubespray',
'rayhanur-rahman/SLIC-Ansible',
'victorock/ansible-playground',
'AndresBott/ansible-autobott',
'BlaiseRitchie/dotfiles',
'CumulusNetworks/citc-openstack-1',
'entercloudsuite/ansible-varnish',
'davepanarese/ansible-varnish',
'progamesigner/playbooks',
'Graee/cri-containerd',
'churchlab/aws-utils',
'angry-tony/ceph-lcm-decapod',
'sakaal/service_commons_ansible',
'sterin/ansible-role-docker-ce',
'cgrates/cgrates',
'containerd/cri',
'gigawhat/laptop-setup',
'progamesigner/playbooks',
'deart2k/build-engineer',
'jonkerj/homeautomation',
'bstascavage/felannisport-ansible',
'rdo-infra/rdo-jobs',
'redhat-performance/satperf',
'FunTimeCoding/ansible-virtual-box',
'jaumecapdevila/test-ansible',
'aojea/k8s-openstack-ansible',
'stonier/groot_ansible',
'alejandrox1/cool_go',
'Mormoroth/kubernetes-cluster',
'rdo-infra/rdo-jobs',
'look-in-a/fivt_tsop',
'rtaneja33/Ansible-Topology-Automation',
'cgrates/cgrates',
'victron/finance_ua',
'GoogleCloudPlatform/magic-modules',
'0x4FCA/dotfiles',
'jtyr/ansible-nginx',
'zh99998/mycard-deploy',
'nudemeth/poc-microservices',
'eggsby/warden',
'atkrad/ansible-role-emqx',
'EJSohn/nvidia-packer-docker-ansible',
'amiller27/dotfiles',
'iotivity/ci-management',
'mpeng819/ubuntu18.04-kubeadmin',
'gun2rin/ansible-desktop',
'stonier/groot_ansible',
'fdziarmagowski/provisioning-cloud-with-ansible',
'vtog/f5-aws-onboard',
'9seconds/ansible-devbox',
'Dripstat/ansible-dripstat-infra-role',
'liptanbiswas/drupal-ansible',
'mfallone/ansible-playbooks',
'ulissiscorrea/devops-challenge',
'hamidyousefi/ansible-docker',
'azywerks/templates',
'KyryloYasko/Graduate-work',
'ciborgue/rig',
'fdziarmagowski/provisioning-cloud-with-ansible',
'stonier/groot_ansible',
'CumulusNetworks/citc-k8s-1',
'jw34/cf_ansible_drupal',
'Monstrofil/wows_simplecrew_dock',
'luodonghua/ansible',
'CumulusNetworks/citc-mesos-1',
'CumulusNetworks/citc-openstack-1',
'angudadevops/kubernetes_ubuntu',
'manoj8928/ansible-ec2',
'monester/ansible-k8s',
'IronCore864/k8s-ansible',
'FarhadF/ansible-playbooks',
'9seconds/ansible-devbox',
'ctonur/vagrant-k8s-cluster-by-ansible',
'bienchu/repo-ali-cloud',
'stfoxfox/auth.app',
'beaker-project/beaker-jenkins-jobs',
'StaticVish/vagrant-k8s-setup-demo',
'maltron/functions',
'open-switch/infra_project-config',
'CumulusNetworks/citc-k8s-1',
'cloud-training/lab-kubernetes',
'DBrianKimmel/PyHouse-ansible',
'sriramsreedhar/ansible',
'tomminux/k8s-in-udf',
'relessawy/dm7_foundation',
'mirkhala/dm7',
'gpe-mw-training/bxms_decision_mgmt_foundations_lab',
'adieu/cue-ansible',
'mirkhala/dm7',
'jjaone/KohaLXC',
'dramirezp/project-config-dev',
'relessawy/dm7_foundation',
'mirkhala/dm7',
'ppst0/ansible-role-dotnet',
'studentenportal/deploy-new',
'shinyaz/ansible-kubernetes-setup',
'mustafarslan/ansible-for-k8s-on-raspbian',
'benkorichard/docker-swarm',
'rtaneja33/Ansible-Topology-Automation',
'amiller27/dotfiles',
'bradwilson/ansible-dev-pc',
'bradwilson/ansible-dev-pc',
'bradwilson/ansible-dev-pc',
'wuerzelchen/RPi_KubernetesCluster',
'iotivity/ci-management',
'gun2rin/ansible-desktop',
'stonier/groot_ansible',
'f5devcentral/f5-agility-labs-containers',
'fdziarmagowski/provisioning-cloud-with-ansible',
'Jooho/ansible-ose3-install',
'rdo-infra/rdo-jobs',
'vtog/f5-aws-onboard',
'9seconds/ansible-devbox',
'ConsortiumGARR/ansiblecharm',
'Dripstat/ansible-dripstat-infra-role',
'pharriso/ansible-playbooks',
'liptanbiswas/drupal-ansible',
'mfallone/ansible-playbooks',
'f5devcentral/f5-agility-labs-containers',
'f5devcentral/f5-agility-labs-containers',
'ulissiscorrea/devops-challenge',
'hamidyousefi/ansible-docker',
'tudorsmt/dotfiles',
'benkorichard/docker-swarm',
'iotivity/ci-management',
'gun2rin/ansible-desktop',
'mpeng819/ubuntu18.04-kubeadmin',
'f5devcentral/f5-agility-labs-containers',
'stonier/groot_ansible',
'fdziarmagowski/provisioning-cloud-with-ansible',
'Dripstat/ansible-dripstat-infra-role',
'rdo-infra/rdo-jobs',
'Jooho/ansible-ose3-install',
'vtog/f5-aws-onboard',
'9seconds/ansible-devbox',
'f5devcentral/f5-agility-labs-containers',
'f5devcentral/f5-agility-labs-containers',
'liptanbiswas/drupal-ansible',
'mfallone/ansible-playbooks',
'pharriso/ansible-playbooks',
'ConsortiumGARR/ansiblecharm',
'ulissiscorrea/devops-challenge',
'hamidyousefi/ansible-docker',
'tudorsmt/dotfiles',
'blcain/ansible-laptop-setup',
'azywerks/templates',
'KyryloYasko/Graduate-work',
'claytono/ansible-infra',
'f5devcentral/f5-agility-labs-containers',
'ciborgue/rig',
'sakaal/com.example_main_ansible',
'FarhadF/ansible-playbooks',
'hub-kubernetes/configuration-management',
'fdziarmagowski/provisioning-cloud-with-ansible',
'stonier/groot_ansible',
'CumulusNetworks/citc-k8s-1',
'jw34/cf_ansible_drupal',
'Adlink-ROS/neuron-simple-playbook',
'fx-giant/chatbot-demo-kit',
'bharatnc/vagrant-k8s',
'Monstrofil/wows_simplecrew_dock',
'bradwilson/ansible-dev-pc',
'TheMiles/ansido',
'femnad/casastrap',
'deart2k/search_engine_ci',
'robertsmieja/ansible-personal-playbooks',
'cgrates/cgrates',
'DannySto/kubernetes-cluster',
'ctonur/vagrant-k8s-cluster-by-ansible',
'mschirbel/k8s-ansible-local',
'femnad/casastrap',
'femnad/casastrap',
'DannySto/kubernetes-cluster',
'Shasthojoy/citc-openstack-1',
'mhrynovets/ansible',
'StaticVish/vagrant-k8s-setup-demo',
'pwolthausen/k8s',
'pwolthausen/k8s',
'ski2per/an5ible',
'9seconds/ansible-devbox',
'shaderecker/ansible-pihole',
'CiscoSystems/third-party-ci-installer',
'eclogue/eclogue',
'x0rzkov/dockerfiles-search',
'luodonghua/ansible',
'FarhadF/ansible-playbooks',
'mustafarslan/ansible-for-k8s-on-raspbian',
'guilhermefariaesilva/Vagrant-ansible-local-k8s',
'9seconds/ansible-devbox',
'bharatnc/vagrant-k8s',
'agentydragon/scripts',
'racoon63/ansible',
'ctonur/vagrant-k8s-cluster-by-ansible',
'mschirbel/k8s-ansible-local',
'bienchu/repo-ali-cloud',
'stfoxfox/auth.app',
'beaker-project/beaker-jenkins-jobs',
'stfoxfox/finance.app',
'StaticVish/vagrant-k8s-setup-demo',
'x0rzkov/dockerfiles-search',
'alghanmi/my-debian-box',
'slashr/vagrant-ansible-kubernetes',
'maltron/functions',
'rob-orr/git-hooks',
'krescent/coding',
'open-switch/infra_project-config',
'lnxjedi/gopherbot',
'brianehlert/ansible-nginx-controller-examples',
'CumulusNetworks/citc-k8s-1',
'x0rzkov/dockerfiles-search',
'cloud-training/lab-kubernetes',
'slashr/vagrant-ansible-kubernetes',
'huntdatacenter/alerta-charm',
'huntdatacenter/alerta-charm',
'krescent/coding',
'harsharachith/MYAnsible',
'DBrianKimmel/PyHouse-ansible',
'sriramsreedhar/ansible',
'Tehsmash/third-party-ci-installer',
'r-cc-c/project-config',
'tomminux/k8s-in-udf',
'relessawy/dm7_foundation',
'OpenSwitchNOS/openswitch-infra-project-config',
'RedHatTraining/business-process-apps-training-lab',
'mirkhala/dm7',
'gpe-mw-training/bxms_decision_mgmt_foundations_lab',
'learnopx/infra_project-config',
'adieu/cue-ansible',
'RedHatTraining/business-process-apps-training-lab',
'mirkhala/dm7',
'jjaone/KohaLXC',
'rdo-infra/rdo-jobs',
'dramirezp/project-config-dev',
'relessawy/dm7_foundation',
'RedHatTraining/business-process-apps-training-lab',
'RedHatTraining/business-process-apps-training-lab',
'mirkhala/dm7',
'coopsymbiotic/coopsymbiotic-ansible',
'gpe-mw-training/bxms_decision_mgmt_foundations_lab',
'StackStorm-Exchange/stackstorm-foreman',
'StackStorm-Exchange/stackstorm-foreman',
'relessawy/dm7_foundation',
'gpe-mw-training/bxms_decision_mgmt_foundations_lab',
'mirkhala/dm7',
'coopsymbiotic/coopsymbiotic-ansible',
'gpe-mw-training/bxms_decision_mgmt_foundations_lab',
'StackStorm-Exchange/stackstorm-foreman',
'StackStorm-Exchange/stackstorm-foreman',
'relessawy/dm7_foundation',
'gpe-mw-training/bxms_decision_mgmt_foundations_lab',
'cyverse-archive/ansible',
'vstconsulting/polemarch',
'zhen00fa/helm-openstack',
'openstack/openstack-helm-infra',
'usha-21/ansible',
'LilyaThebti/demo-test',
'evrardjp/charts',
'op317q/openstack-helm-infra',
'brunocarvalhodearaujo/openstack-helm-infra',
'ian-howell/keystone-argo-demo',
'arun2908/prathyu',
'x0rzkov/dockerfiles-search',
'and-1/openstack-helm-infra',
'zhen00fa/openstack-helm-infra',
'bradwilson/ansible-dev-pc',
'cb371j/osh-infra',
'ak89224/GFA',
'packit-service/ogr',
'kazmardev/falco',
'Azure/sg-aks-workshop',
'ITEFARMAT/sg-aks-workshop',
'joalder/securing-kubernets-workshop',
'commercialhaskell/all-cabal-metadata',
'ITEFARMAT/sg-aks-workshop',
'joalder/securing-kubernets-workshop',
'commercialhaskell/all-cabal-metadata',
'CloudNativeGBB/cluster-baseline',
'qubole/charts']

# %%
repos_yaml_unique = set(repos_yaml)
len(repos_yaml_unique)
# Out:
# 172

# %%
result = search_github('ansible','yaml')
rep_list = []
for res in result:
    print(res.repository.full_name)
# Out:
# You have 30/30 API calls remaining
# alghanmi/my-debian-box
# jtyr/ansible-telegraf
# jeanfrancoisgratton/mainline
# Sebor/ansible
# evgeniy-novikov/zabbix-agent
# CumulusNetworks/citc-mesos-1
# rayhanur-rahman/CSC503-Project
# jtyr/ansible-prometheus
# vecin2/dotfiles
# FunTimeCoding/ansible-backports
# evgeniy-novikov/zabbix-agent
# hemidactylus/ostracion
# slegs/cgrates-docker
# xinghu0164/TouchFrame-Group
# xinghu0164/TouchFrame-Group
# xinghu0164/TouchFrame-Group
# agude/ansible
# Mirantis/ceph-lcm
# Shasthojoy/citc-openstack-1
# 9seconds/ansible-devbox
# xinghu0164/TouchFrame-Group
# jtyr/ansible-alertmanager
# xinghu0164/TouchFrame-Group
# cgrates/cgrates
# ilyakov/playing_with_ansible_innova
# usamacheema786/kubespray
# dragon699/pg_upgrade
# AndresBott/ansible-autobott
# CumulusNetworks/citc-openstack-1
# victorock/ansible-playground
# davepanarese/ansible-varnish
# progamesigner/playbooks
# entercloudsuite/ansible-varnish
# usamacheema786/kubespray
# ...

# %%
repos_yaml2 = ['alghanmi/my-debian-box',
'jtyr/ansible-telegraf',
'jeanfrancoisgratton/mainline',
'Sebor/ansible',
'evgeniy-novikov/zabbix-agent',
'CumulusNetworks/citc-mesos-1',
'rayhanur-rahman/CSC503-Project',
'paulbovbel/ansible-personal',
'vecin2/dotfiles',
'jtyr/ansible-prometheus',
'FunTimeCoding/ansible-backports',
'evgeniy-novikov/zabbix-agent',
'paulbovbel/ansible-personal',
'hemidactylus/ostracion',
'Mirantis/ceph-lcm',
'jtyr/ansible-alertmanager',
'slegs/cgrates-docker',
'xinghu0164/TouchFrame-Group',
'xinghu0164/TouchFrame-Group',
'xinghu0164/TouchFrame-Group',
'agude/ansible',
'Shasthojoy/citc-openstack-1',
'9seconds/ansible-devbox',
'xinghu0164/TouchFrame-Group',
'cgrates/cgrates',
'xinghu0164/TouchFrame-Group',
'ilyakov/playing_with_ansible_innova',
'usamacheema786/kubespray',
'victorock/ansible-playground',
'rayhanur-rahman/SLIC-Ansible',
'AndresBott/ansible-autobott',
'BlaiseRitchie/dotfiles',
'CumulusNetworks/citc-openstack-1',
'entercloudsuite/ansible-varnish',
'progamesigner/playbooks',
'Graee/cri-containerd',
'davepanarese/ansible-varnish',
'churchlab/aws-utils',
'angry-tony/ceph-lcm-decapod',
'sakaal/service_commons_ansible',
'sterin/ansible-role-docker-ce',
'cgrates/cgrates',
'containerd/cri',
'gigawhat/laptop-setup',
'progamesigner/playbooks',
'deart2k/build-engineer',
'jonkerj/homeautomation',
'bstascavage/felannisport-ansible',
'rdo-infra/rdo-jobs',
'redhat-performance/satperf',
'FunTimeCoding/ansible-virtual-box',
'jaumecapdevila/test-ansible',
'aojea/k8s-openstack-ansible',
'stonier/groot_ansible',
'alejandrox1/cool_go',
'Mormoroth/kubernetes-cluster',
'rdo-infra/rdo-jobs',
'look-in-a/fivt_tsop',
'rtaneja33/Ansible-Topology-Automation',
'cgrates/cgrates',
'andibraeu/myPlaybooks',
'bradwilson/ansible-dev-pc',
'YaoZengzeng/comments',
'jacobborella/myproject',
'brianehlert/ansible-nginx-controller-examples',
'brianehlert/ansible-nginx-controller-examples',
'deepak7093/ansible-arangodb',
'9seconds/ansible-devbox',
'vtog/aws-container-lab',
'zhoumingjun/ubuntu-ansible-playbooks',
'FunTimeCoding/ansible-jenkins',
'akraino-edge-stack/ta-caas-install',
'dariosky/ansible-mybox',
'rdo-infra/rdo-jobs',
'cgrates/cgrates',
'Racknaraock/SampleEquinix',
'zioproto/kolla-on-SWITCHengines',
'yusraahmed/myfirstrepo',
'vtog/aws-container-lab',
'Mormoroth/kubernetes-cluster',
'hyperledger/sawtooth-contrib',
'shinyaz/ansible-kubernetes-setup',
'sakaal/com.example_main_ansible',
'shashoul/Ansible',
'amiller27/dotfiles',
'fandoghpaas/k8s-cluster',
'rhoriguchi/ansible_setup',
'roberto0180/ansible-testing',
'cgrates/cgrates',
'flant/mcrouter',
'brianehlert/ansible-nginx-controller-examples',
'brianehlert/ansible-nginx-controller-examples',
'slegs/cgrates-docker',
'deepak7093/ansible-arangodb',
'9seconds/ansible-devbox',
'vtog/aws-container-lab',
'zhoumingjun/ubuntu-ansible-playbooks',
'diederdas/at-test',
'FunTimeCoding/ansible-jenkins',
'akraino-edge-stack/ta-caas-install',
'dariosky/ansible-mybox',
'rdo-infra/rdo-jobs',
'cgrates/cgrates',
'InformaticsMatters/ansible-bastion',
'Racknaraock/SampleEquinix',
'zioproto/kolla-on-SWITCHengines',
'yusraahmed/myfirstrepo',
'vtog/aws-container-lab',
'Mormoroth/kubernetes-cluster',
'hyperledger/sawtooth-contrib',
'shinyaz/ansible-kubernetes-setup',
'sakaal/com.example_main_ansible',
'shashoul/Ansible',
'amiller27/dotfiles',
'fandoghpaas/k8s-cluster',
'rhoriguchi/ansible_setup',
'sergkondr-ansible/apt',
'roberto0180/ansible-testing',
'ziplex/ansible-projects',
'cgrates/cgrates',
'vtog/f5-aws-onboard',
'9seconds/ansible-devbox',
'ConsortiumGARR/ansiblecharm',
'Dripstat/ansible-dripstat-infra-role',
'mfallone/ansible-playbooks',
'ulissiscorrea/devops-challenge',
'hamidyousefi/ansible-docker',
'azywerks/templates',
'KyryloYasko/Graduate-work',
'claytono/ansible-infra',
'ciborgue/rig',
'FarhadF/ansible-playbooks',
'fdziarmagowski/provisioning-cloud-with-ansible',
'stonier/groot_ansible',
'CumulusNetworks/citc-k8s-1',
'jw34/cf_ansible_drupal',
'deart2k/search_engine_ci',
'robertsmieja/ansible-personal-playbooks',
'cgrates/cgrates',
'mhrynovets/ansible',
'Shasthojoy/citc-openstack-1',
'StaticVish/vagrant-k8s-setup-demo',
'9seconds/ansible-devbox',
'pwolthausen/k8s',
'pwolthausen/k8s',
'ski2per/an5ible',
'shaderecker/ansible-pihole',
'CiscoSystems/third-party-ci-installer',
'ulissiscorrea/devops-challenge',
'luodonghua/ansible',
'pwolthausen/k8s',
'pwolthausen/k8s',
'luodonghua/ansible',
'eclogue/eclogue',
'CumulusNetworks/citc-mesos-1',
'CumulusNetworks/citc-openstack-1',
'manoj8928/ansible-ec2',
'monester/ansible-k8s',
'kiddikai/ansible-kubernetes',
'googollee/my_sys',
'IronCore864/k8s-ansible',
'x0rzkov/dockerfiles-search',
'Adlink-ROS/neuron-simple-playbook',
'9seconds/ansible-devbox',
'bharatnc/vagrant-k8s',
'racoon63/ansible',
'mschirbel/k8s-ansible-local',
'ctonur/vagrant-k8s-cluster-by-ansible',
'bienchu/repo-ali-cloud',
'stfoxfox/auth.app',
'beaker-project/beaker-jenkins-jobs',
'StaticVish/vagrant-k8s-setup-demo',
'x0rzkov/dockerfiles-search',
'alghanmi/my-debian-box',
'volat1977/project',
'maltron/functions',
'open-switch/infra_project-config',
'rob-orr/git-hooks',
'lnxjedi/gopherbot',
'brianehlert/ansible-nginx-controller-examples']

# %%
repos_unique_yaml2 = set(repos_yaml2)
len(repos_unique_yaml2)
# Out:
# 120

# %%
result = search_github('ansible','yml')
for r in result:
    print(r.repository.full_name)
# Out:
# You have 30/30 API calls remaining
# markokole/iac-aws-hadoop
# aolwas/ansible-playbooks
# yangwang166/hwx_ansible
# hubakias/ansible
# ekapusta/docker-ansibled-centos
# fabricioboreli/ansible-role-mariadb
# asifkhan7000/ansible-hortonworks
# pacificbreeze007/DevOps
# foxutech/wazuh-ansible
# farhana-khan/ansible-hortonworks
# Thulium-Drake/ansible-role-apt
# vikramjanarthanan/ansible-hortonworks
# banna2019/devops-project
# caseyrichins/ansible-paranoid
# myprojectphoenix/HDPonAWSwithANSIBLE
# gridgentoo/ansible-hortonworks
# fanttazio/AWX_Test
# foxutech/wazuh-ansible
# patalwell/hdp-ansible
# arunkumarmurugesan/anisble
# zackmeso/ansible-kerberized-hw-cluster
# venkey1185/ansible-hdf
# Misk77/examApp
# vishwas-devops/Assignments
# rinnerr/openio-rawx
# open-io/ansible-role-openio-repository
# banna2019/study-package
# softasap/sa-python
# opendevshop/devshop
# robertshell22/d8-thunder-vm
# NLNOG/ring-ansible
# tenhishadow/salt_minion
# stevestrutt/roleclone
# ...

# %%
repos_yml2 = ['markokole/iac-aws-hadoop',
'yangwang166/hwx_ansible',
'ekapusta/docker-ansibled-centos',
'hubakias/ansible',
'aolwas/ansible-playbooks',
'fabricioboreli/ansible-role-mariadb',
'asifkhan7000/ansible-hortonworks',
'foxutech/wazuh-ansible',
'pacificbreeze007/DevOps',
'farhana-khan/ansible-hortonworks',
'arunkumarmurugesan/anisble',
'Thulium-Drake/ansible-role-apt',
'myprojectphoenix/HDPonAWSwithANSIBLE',
'caseyrichins/ansible-paranoid',
'gridgentoo/ansible-hortonworks',
'banna2019/devops-project',
'vikramjanarthanan/ansible-hortonworks',
'alikins/strawman_mazer_shelf',
'robertshell22/d8-thunder-vm',
'Misk77/examApp',
'patalwell/hdp-ansible',
'foxutech/wazuh-ansible',
'rinnerr/openio-rawx',
'open-io/ansible-role-openio-repository',
'NLNOG/ring-ansible',
'softasap/sa-docker',
'renanmfd/smartbet',
'MonkiiBuilt/code-test-drupal',
'vishwas-devops/Assignments',
'venkey1185/ansible-hdf',
'venkey1185/ansible-hdf',
'GluuFederation/acceptance-tests',
'tenhishadow/salt_minion',
'andrewfandrew/horsepower',
'opendevshop/devshop',
'softasap/sa-python',
'softasap/sa-uwsgi',
'adamkingit/bluemix-openstack-deploy',
'stevestrutt/roleclone',
'che607/test_1',
'banna2019/study-package',
'fordse3/Samedits',
'sivavadivel/ansible_hwx_model',
'chris-greatens/drupal-magento',
'yangwang166/hwx_ansible',
'Jason-Jongjin-Lim/ocp_hosts_references',
'markokole/iac-aws-hadoop',
'JugglerX/drydock',
'softasap/sa-postgres-workplace',
'BriceMichalski/tp-devops-ansible',
'darkwizard242/ansible-role-docker',
'flashashen/zombiepoetryproject',
'silbermantel/all_my_hosts',
'shelleg/ansible-role-rabbitmq',
'nephelaiio/ansible-role-elastic-repo',
'gsteinhoff/ut-first-test',
'openstack/openstack-ansible-rabbitmq_server',
'coetzeer/ansible-seedbox',
'c-po/ansible-role-unifi',
'rinnerr/openio-rawx',
'IBMCloudDevOps/travis-openstack-deploy',
'banna2019/devops-project',
'M4XW3L-8/ansible-workstation',
'JefMuller/ansible',
'c-po/ansible-role-unifi',
'elevatedthird/nyc-books-api-professional-development',
'arunkumarmurugesan/anisble',
'silbermantel/all_my_hosts',
'geerlingguy/ansible-role-php-versions',
'owlick/TOSHIBA',
'd1netreus/wazuh-ansible',
'o-saddane/drupal-vm',
'hortonworks/ansible-hortonworks',
'fotuzlab/dvvm',
'shakeme/localkube',
'alexburrows/commerceauction',
'luk82/drupal-vm-template',
'pacificbreeze007/DevOps',
'asifkhan7000/ansible-hortonworks',
'softasap/sa-box-awx',
'SoftStackFactory/ssf-devops',
'p-avery/wazuh',
'cdelgehier/ansible-role-openio-sds',
'oops-to-devops/traefik_box',
'qngo-windwalker/opigno',
'banna2019/devops-project',
'DipakShrestha18/corporate-d8-react',
'open-io/ansible-role-openio-repository',
'liujun1990/ansible-k8s-tls',
'liujun1990/ansible-k8s-tls',
'faisalzafaruae/ansible-hortonworks',
't324inc/d324-vm',
'IBMCloudDevOps/bluemix-openstack-deploy',
'farhana-khan/ansible-hortonworks',
'plamen-penev-ffw/shaolin',
'banna2019/study-package',
'fayaaz/spacewalk.ansible',
'GieronAdam/edu-drupal',
'kevit/overlay',
'kevit/overlay',
'aka-cafu/ansible',
'cactus-blossom-it-services-limited/baudelaire',
'vinous22/MoviesProject',
'vicenteg/mapr-repo-mirror',
'NYULibraries/mediacommons-vm',
'myprojectphoenix/HDPonAWSwithANSIBLE',
'gmauro/ansible-ice',
'Marie-L/NewsLanding',
'redhat-cop/containers-quickstarts',
'chauanhtuandl/ansible-role-php-versions',
'andrelohmann/ansible-role-gitlab',
'rayhanur-rahman/CSC503-Project',
'Zuiev/yca',
'softasap/sa-sentry',
'maxxko/segment.nginx',
'gridgentoo/ansible-hortonworks',
'buldug/dugsite',
'willpllc/infra-homework',
'masumndc1/lxd-cluster',
'JackyChenNgu/tripleo-quickstart',
'kevit/overlay',
'cristiroma/bioland',
'aldunchev/drupal-json-api',
'venkey1185/ansible-hdp',
'stkrp/ansible-sandbox',
'IndikaKuma/sodalite',
'zxpup/ansible-role-php-versions',
'rayhanur-rahman/CSC503-Project',
'softasap/sa-uwsgi-container',
'd1netreus/wazuh-ansible',
'philip-preston/ti_test',
'xvanced/modx-server',
'CioRodica/kickstart',
'rayhanur-rahman/CSC503-Project',
'CESNET/perun-ansible-shibboleth',
'dantin/HDP-Ansible',
'softasap/sa-jupyterhub',
'p-avery/wazuh',
'rayhanur-rahman/CSC503-Project',
'dj-wasabi/ansible-telegraf',
'gapple/cnibdemo',
'rcbops/openstack-ops',
'wendb/ansible-hortonworks',
'screenlock/one',
'Fluxusio/vm-winnergroup',
'marvinpinto/laptop',
'AnotherKamila/bsdops',
'jonnymac15/movieproject',
'JackyChenNgu/tripleo-quickstart',
'jonnymac15/jonsrecipes',
'R4scal/home-lab',
'hashnfv/hashnfv-qtip',
'hortonworks/ansible-hortonworks',
'jaredledvina/sensu-go-ansible',
'galexrt/ansible-cockpit',
'joshbenner/ansible-role-sensu',
'darkwizard242/ansible-role-azurecli',
'18414/kubernetes-setup',
'testjatin93/ansible3',
'MaxBab/bareos-ansible',
'alikins/strawman_mazer_shelf',
'alikins/strawman_mazer_shelf',
'BenjaminLSmith/pi-ansible',
'mattiast/dotfiles',
'gaelL/molecule-test',
'eellak/ansible',
'lquessenberry/scaling-octo-enigma',
'deceptionlogic/ansible-deception-agent',
'morganllj/ansible-playbooks',
'renanmfd/smartbet',
'renanmfd/smartbet',
'MonkiiBuilt/code-test-drupal',
'MonkiiBuilt/code-test-drupal',
'kevit/overlay',
'kevit/overlay',
'juttayaya/devops',
'nofuturekid/ansible',
'riponbanik/ansible-role-foreman',
'd0pang/ansible-hdp3.1',
'cmihai-ansible/jenkins',
'itlongtruong/configure-ansible',
'OpenNebula/addon-host-provision',
'kgatjens/d8_vm_vagrant',
'SpivEgin/roles',
'laurentedel/ansible-hdp',
'pugna0/ansible',
'sajjadwasim/test2',
'belbassy/spacefed',
'VladimirChudovskiy/learn_drupalvm',
'devopspoc-ram/sensu',
'devopspoc-ram/sensu',
'pajavyskocil/elk_test',
'tenhishadow/pve_on_debian',
'krzysztof-ksiazek/cc-k8s',
'wakwanza/ansible-role-arangodb',
'hensing/dotfiles',
'andrelohmann/ansible-role-gitlab_docker_runner',
'mechaphish/setup',
'brad-x/ansible-sysadmin',
'andrewwh/ansible-workstation',
'softasap/sa-docker',
'spolex/hwk-ansible',
'rlex/ansible-role-influxdb',
'toddstoffel/cdc_demo',
'pacificbreeze007/devops_yard',
'vikramjanarthanan/ansible-hortonworks',
'CreatorDev/DeviceServer',
'R4scal/home-lab',
'ceyounger/ansible',
'hortonworks/ansible-hortonworks',
'openstack/tripleo-quickstart',
'AnotherKamila/bsdops',
'rayhanur-rahman/CSC503-Project',
'NYULibraries/mediacommons-vm',
'dj-wasabi/ansible-ossec-server',
'hieuvecto/demo3boxes',
'MinistryOfJusticeCZ/ansible-linuxdvz',
'evanhsu/ansible-shared-host',
'uchida/ansible-role-nvidia-repo',
'evgenia-tkachenko/drupal_events',
'zx1986/phpday-ansible',
'evalero/ansible-atom',
'yuyicai/kubernetes-ha-ansible',
'DistributedSystemsGroup/sysadmin-dsp',
'wazuh/wazuh-ansible',
'bhcleek/ansible-playbooks',
'thepg/Ansible-HW-kerberized',
'pawankkamboj/kubernetes-ansible',
'LEARNAcademy/devpass-devops',
'nikaro/ansible-role-nginx',
'MaxBab/bareos-ansible',
'blurblah/ansible-role-mesos-slave',
'blurblah/ansible-role-mesos-master',
'masumndc1/lxd-cluster',
'mhalano/ansible-role-atom',
'mrleerkotte/ansible-role-unifi',
'Malek23923/bef',
'skipidar/Vagrant_Templates',
'skipidar/Vagrant_Templates',
'farhana-khan/ansible-hortonworks',
'skipidar/Vagrant_Templates',
'rohanraja/codevine',
'opnfv/qtip',
'jaredledvina/sensu-go-ansible',
'mmolinac/LinuxToolset',
'rayhanur-rahman/CSC503-Project',
'rayhanur-rahman/CSC503-Project',
'openstack/tripleo-quickstart',
'openstack/tripleo-quickstart',
'nikaro/ansible-role-nginx',
'blurblah/ansible-role-mesos-slave',
'M4XW3L-8/ansible-workstation',
'newstar123/VM---master',
'varshineevenkatesan/ambari_with_flink',
'dom18fr/sudradiobox',
'oscpe262/ansible-role-cockpit',
'DevOps-Testing/AnsibleController',
'ju2wheels/ansible-galaxy-ju2wheels.pyenv',
'wellcometrust/upd',
'MiguelJulia/GCC2019_GalaxyAnsibleDeplyoment_CVMFS',
'Shahriar567/Spark-Hadoop_ClusterSetup',
'Shahriar567/Spark-Hadoop_ClusterSetup',
'OpenNebula/addon-host-provision',
'openstack/tripleo-quickstart',
'laurentedel/ansible-hdp',
'nfaction/ansible-bootstrap',
'kgatjens/d8_vm_vagrant',
'phcaguiar/infra-financial-products-tribe-common-vsts-agents',
'belbassy/spacefed',
'SpivEgin/roles',
'faisalzafaruae/ansible-hortonworks',
'softasap/sa-docker',
'spolex/hwk-ansible',
'rlex/ansible-role-influxdb',
'toddstoffel/cdc_demo',
'open-io/ansible-role-openio-sds',
'Provizanta/ansible-role-beats',
'fititnt/ap-application-load-balancer',
'pacificbreeze007/devops_yard',
'vikramjanarthanan/ansible-hortonworks',
'CreatorDev/DeviceServer',
'R4scal/home-lab',
'phpguy84/ed-t1',
'hashnfv/hashnfv-qtip',
'ceyounger/ansible',
'hortonworks/ansible-hortonworks',
'softasap/sa-chatops-errbot',
'jaredledvina/sensu-go-ansible',
'galexrt/ansible-cockpit',
'joshbenner/ansible-role-sensu',
'darkwizard242/ansible-role-azurecli',
'SpaceHotDog/scriptsDB',
'18414/kubernetes-setup',
'sukujgrg/kubernetes-do-ansible',
'rayhanur-rahman/CSC503-Project',
'usegalaxy-eu/infrastructure-playbook',
'sivavadivel/ansible_hwx_model',
'Provizanta/ansible-role-elasticsearch',
'ITSvitCo/Datacharmer',
'testjatin93/ansible3',
'open-io/ansible-role-openio-sds',
'Provizanta/ansible-role-beats',
'fititnt/ap-application-load-balancer',
'pacificbreeze007/devops_yard',
'vikramjanarthanan/ansible-hortonworks',
'CreatorDev/DeviceServer',
'R4scal/home-lab',
'phpguy84/ed-t1',
'hashnfv/hashnfv-qtip',
'ceyounger/ansible',
'hortonworks/ansible-hortonworks',
'softasap/sa-chatops-errbot',
'jaredledvina/sensu-go-ansible',
'galexrt/ansible-cockpit',
'joshbenner/ansible-role-sensu',
'darkwizard242/ansible-role-azurecli',
'SpaceHotDog/scriptsDB',
'18414/kubernetes-setup',
'sukujgrg/kubernetes-do-ansible',
'rayhanur-rahman/CSC503-Project',
'usegalaxy-eu/infrastructure-playbook',
'sivavadivel/ansible_hwx_model',
'Provizanta/ansible-role-elasticsearch',
'ITSvitCo/Datacharmer',
'testjatin93/ansible3',
'MaxBab/bareos-ansible',
'dokuhebi/home_config',
'dokuhebi/home_config',
'alikins/strawman_mazer_shelf',
'alikins/strawman_mazer_shelf',
'kevit/overlay',
'fordse3/Samedits',
'nofuturekid/ansible',
'jeffhung/ansible-kibana',
'piotrkpc/tripleo-quickstart-configs',
'cmihai-ansible/jenkins',
'thingsym/vaw',
'alexblackie/bootstart',
'HugoPeters1024/config',
'ernstp/ansible',
'uw-dims/ansible-dims-playbooks',
'usegalaxy-eu/jenkins-worker',
'rayhanur-rahman/CSC503-Project',
'tagliateller/urban-train',
'thingsym/vap',
'renanmfd/meninadasbalas',
'rlex/ansible-role-zabbix-agent',
'andrewfandrew/horsepower',
'andrewfandrew/horsepower',
'chrissnyder2337/symfony-ansible-starter-vm',
'leiting920708/ansible',
'tjeastman/ansible-playbooks',
'jan-warchol/ansible-workstation-setup',
'rayhanur-rahman/CSC503-Project',
'jeffhung/ansible-logstash',
'UtrechtUniversity/yoda-ansible',
'kaminek/playbooks',
'adi4dpeople/ansible',
'btmash/drupal_ansible',
'Feng-Shui/whitesite',
'jeffhung/ansible-logstash',
'rayhanur-rahman/CSC503-Project',
'UtrechtUniversity/yoda-ansible',
'henderiw/ansible',
'cmihai-ansible/cookiecutter-role',
'honzamach/ansible-role-mentat-dev',
'kaminek/playbooks',
'chrissnyder2337/symfony-ansible-starter-vm',
'ernstp/ansible',
'egeneralov/timescaledb',
'DistributedSystemsGroup/sysadmin-dsp',
'che607/test_1',
'che607/test_1',
'Modulus/ansible-forman',
'marinoska/vagrant-ansible',
'JackyChenNgu/tripleo-quickstart',
'JackyChenNgu/tripleo-quickstart',
'deep-ty/ansible-docker-setup',
'deep-ty/ansible-docker-setup',
'gitclonparis/ansi',
'rayhanur-rahman/CSC503-Project',
'Feng-Shui/whitesite',
'JackyChenNgu/tripleo-quickstart',
'kmane-mem/ansible',
'JugglerX/drydock',
'csm789/OMT-Ansible',
'marvinpinto/laptop',
'UtrechtUniversity/yoda-ansible',
'reyesg/vagrant',
'oops-to-devops/traefik_box',
'rayhanur-rahman/CSC503-Project',
'kmane-mem/ansible',
'JugglerX/drydock',
'JackyChenNgu/tripleo-quickstart',
'gitclonparis/ansi',
'ipr-cnrs/openmanage',
'UtrechtUniversity/yoda-ansible',
'marvinpinto/laptop',
'csm789/OMT-Ansible',
'jpuellma/ansible.old',
'flyhard/awsHashicorpStack',
'equalitie/eqpress',
'seungkyua/my-kubespray',
'softasap/sa-box-awx',
'FinalDes/ansible-mongodb',
'oops-to-devops/traefik_box',
'colinlabs/ansible-kube',
'egi-qc/ansible-umd',
'aquarion/autopelago',
'Provizanta/ansible-role-logstash',
'Modulus/ansible-forman',
'FinalDes/ansible-nginx',
'rameshkalirawana/gra',
'egormin/ansible_portable',
'uchida/ansible-role-nvidia-driver',
'che607/decoupled_project',
'filusATpsc/sdaia-xsede',
'fotuzlab/dvvm',
'fotuzlab/dvvm',
'JackyChenNgu/tripleo-quickstart']

# %%
unique_repos_yml2 = set(repos_yml2)

# %%
print(len(unique_repos_yml),len(unique_repos_yml2),'\n',len(repos_yaml_unique),len(repos_unique_yaml2))
# Out:
# 422 267
#  172 120

# %%
def union(lst1, lst2): 
    final_list = list(set(lst1) | set(lst2)) 
    return final_list

# %%
final_yml = union(unique_repos_yml,unique_repos_yml2)
len(final_yml)
# Out:
# 440

# %%
final_yaml = union(repos_yaml_unique,repos_unique_yaml2)
len(final_yaml)
# Out:
# 197

# %%
with open('yaml_reps.txt','w') as f:
    for item in final_yaml:
        f.write(item)
        f.write('\n')
with open('yaml_reps.csv', 'w', newline='') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(final_yaml)

# %%
with open('yml_reps.txt','w') as f:
    for item in final_yml:
        f.write(item)
        f.write('\n')
with open('yml_reps.csv', 'w', newline='') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(final_yml)

# %%
with open('yml_repos.pkl', 'wb') as output_file:
    pickle.dump(final_yml, output_file)

# %%
with open('yml_repos.pkl', 'rb') as input_file:
    yml_repos = pickle.load(input_file)
yml_repos
# Out:
# ['likg/ansible-role-apt-repo-sury-org',
#  'hieuvecto/demo3boxes',
#  'flyhard/awsHashicorpStack',
#  'gapple/cnibdemo',
#  'juttayaya/devops',
#  'openstack/openstack-ansible-ops',
#  'uw-dims/ansible-dims-playbooks',
#  'darkwizard242/ansible-role-polychromatic',
#  'oops-to-devops/traefik_box',
#  'nfaction/ansible-bootstrap',
#  'caseyrichins/ansible-paranoid',
#  'rohanraja/codevine',
#  'darkwizard242/ansible-role-docker',
#  'andrelohmann/ansible-role-gitlab_docker_runner',
#  'brianannis/ubuntu-bootstrap',
#  'liujun1990/ansible-k8s-tls',
#  'ansible-collection-migration/notstdlib.moveitallout',
#  'alexandrdnlv/DrupalVM-D8stable',
#  'plamen-penev-ffw/shaolin',
#  'ernstp/ansible',
#  'seungkyua/my-kubespray',
#  'IBMCloudDevOps/travis-openstack-deploy',
#  'oops-to-devops/mysql_box',
#  'luk82/drupal-vm-template',
#  'tenhishadow/pve_on_debian',
#  'usegalaxy-eu/infrastructure-playbook',
#  'codeghar/ubuntu-dev-box-with-ansible',
#  'vikramjanarthanan/ansible-hortonworks',
# ...

# %%
with open('yaml_repos.pkl', 'wb') as output_file:
    pickle.dump(final_yaml, output_file)

# %%
with open('yaml_repos.pkl', 'rb') as input_file:
    yaml_repos = pickle.load(input_file)
yaml_repos
# Out:
# ['mpeng819/ubuntu18.04-kubeadmin',
#  'AndresBott/ansible-autobott',
#  'Jooho/ansible-ose3-install',
#  'agentydragon/scripts',
#  'dariosky/ansible-mybox',
#  'OpenSwitchNOS/openswitch-infra-project-config',
#  'packit-service/ogr',
#  'hemidactylus/ostracion',
#  'stonier/groot_ansible',
#  'liptanbiswas/drupal-ansible',
#  'InformaticsMatters/ansible-bastion',
#  'jtyr/ansible-nginx',
#  '0x4FCA/dotfiles',
#  'eclogue/eclogue',
#  'mfallone/ansible-playbooks',
#  'atkrad/ansible-role-emqx',
#  'tomminux/k8s-in-udf',
#  'entercloudsuite/ansible-varnish',
#  'harsharachith/MYAnsible',
#  'shinyaz/ansible-kubernetes-setup',
#  'jtyr/ansible-alertmanager',
#  'Monstrofil/wows_simplecrew_dock',
#  'RedHatTraining/business-process-apps-training-lab',
#  'CloudNativeGBB/cluster-baseline',
#  'GoogleCloudPlatform/magic-modules',
#  'ciborgue/rig',
#  'ppst0/ansible-role-dotnet',
#  'bradwilson/ansible-dev-pc',
#  'kazmardev/falco',
#  'StaticVish/vagrant-k8s-setup-demo',
# ...

# %%
keywords = ['ansible', 'ansible playbook', 'ansible deployment']

# %%
def search_github_repositories(keywords):
    
    query = '+'.join(keywords) + '+in:readme+in:description+archived:false'
    result = g.search_repositories(query, 'stars', 'desc')
 
    print(f'Found {result.totalCount} repo(s)')
 
    for repo in result:
        print(f'{repo.url}')

# %%
search_github_repositories(keywords)
# Out:
# Found 1000 repo(s)
# https://api.github.com/repos/ansible/ansible-examples
# https://api.github.com/repos/openstack/openstack-ansible
# https://api.github.com/repos/ceph/ceph-ansible
# https://api.github.com/repos/ftao/vpn-deploy-playbook
# https://api.github.com/repos/hortonworks/ansible-hortonworks
# https://api.github.com/repos/jlund/mazer-rackham
# https://api.github.com/repos/splunk/splunk-ansible
# https://api.github.com/repos/itwars/k3s-ansible
# https://api.github.com/repos/objectrocket/ansible-hadoop
# https://api.github.com/repos/CorbanR/ansible-serverdensity
# https://api.github.com/repos/k8sre/k8s
# https://api.github.com/repos/mattmakai/sf-django
# https://api.github.com/repos/StackStorm/ansible-st2
# https://api.github.com/repos/tsg/packetbeat-deploy
# https://api.github.com/repos/plone/ansible-playbook
# https://api.github.com/repos/centos-opstools/opstools-ansible
# https://api.github.com/repos/kubevirt/kubevirt-ansible
# ...

# %%
result_list = ['https://api.github.com/repos/ansible/ansible-examples',
'https://api.github.com/repos/openstack/openstack-ansible',
'https://api.github.com/repos/ceph/ceph-ansible',
'https://api.github.com/repos/ftao/vpn-deploy-playbook',
'https://api.github.com/repos/hortonworks/ansible-hortonworks',
'https://api.github.com/repos/jlund/mazer-rackham',
'https://api.github.com/repos/splunk/splunk-ansible',
'https://api.github.com/repos/itwars/k3s-ansible',
'https://api.github.com/repos/objectrocket/ansible-hadoop',
'https://api.github.com/repos/CorbanR/ansible-serverdensity',
'https://api.github.com/repos/k8sre/k8s',
'https://api.github.com/repos/mattmakai/sf-django',
'https://api.github.com/repos/StackStorm/ansible-st2',
'https://api.github.com/repos/tsg/packetbeat-deploy',
'https://api.github.com/repos/plone/ansible-playbook',
'https://api.github.com/repos/centos-opstools/opstools-ansible',
'https://api.github.com/repos/kubevirt/kubevirt-ansible',
'https://api.github.com/repos/bradymholt/ansible-rails',
'https://api.github.com/repos/InsightDataScience/ansible-playbook',
'https://api.github.com/repos/rgee0/openfaas-on-digitalocean',
'https://api.github.com/repos/jbinto/ansible-ubuntu-rails-server',
'https://api.github.com/repos/adfinis-sygroup/foreman-ansible',
'https://api.github.com/repos/mina-alber/wireguard-ansible',
'https://api.github.com/repos/sergevs/ansible-cloudera-hadoop',
'https://api.github.com/repos/Kami/ansible-postgresql',
'https://api.github.com/repos/GoogleCloudPlatform/compute-ansible-gluster',
'https://api.github.com/repos/ahmedfaragmostafa/Ansible-in-action',
'https://api.github.com/repos/oguya/cis-ubuntu-14-ansible',
'https://api.github.com/repos/ghrst/Kamailio-HA',
'https://api.github.com/repos/ksylvan/docker-mail-server',
'https://api.github.com/repos/rcbops/ansible-lxc-rpc',
'https://api.github.com/repos/jriguera/ansible-ironic-standalone',
'https://api.github.com/repos/faer615/greenplum',
'https://api.github.com/repos/att-comdev/halcyon-kubernetes',
'https://api.github.com/repos/bee-keeper/aws-ansible-django-deployment',
'https://api.github.com/repos/jsphpl/laravan',
'https://api.github.com/repos/yasensim/vsphere-lab-deploy',
'https://api.github.com/repos/cvezalis/ansible-weblogic-fmw-infra-12c-R2',
'https://api.github.com/repos/Kami/ansible-cassandra',
'https://api.github.com/repos/k8s-community/cluster-deploy',
'https://api.github.com/repos/rcbops/rpc-maas',
'https://api.github.com/repos/ipspace/MPLS-infrastructure',
'https://api.github.com/repos/InformatiQ/sensu-ansible',
'https://api.github.com/repos/drewkerrigan/ansible-magento',
'https://api.github.com/repos/norberttech/ansible-symfony2-deploy',
'https://api.github.com/repos/eucalyptus/ansible-playbooks',
'https://api.github.com/repos/amarao/ansible-flyway',
'https://api.github.com/repos/jkzhao/ansible-godseye',
'https://api.github.com/repos/mikeblum/redis-playbook',
'https://api.github.com/repos/poanetwork/deployment-playbooks',
'https://api.github.com/repos/openstack/tripleo-validations',
'https://api.github.com/repos/melihovv/initial-webserver-setup',
'https://api.github.com/repos/switch-ch/owncloud-ansible',
'https://api.github.com/repos/alexjbush/ansible-hadoop-asap',
'https://api.github.com/repos/bwhaley/asg_deploy',
'https://api.github.com/repos/ARTbio/GalaxyKickStart',
'https://api.github.com/repos/jgrowl/ansible-playbook-ldap',
'https://api.github.com/repos/zwindler/ansible-deploy-vmware-guest',
'https://api.github.com/repos/jrisch/ansible-xenserver-vm-deploy',
'https://api.github.com/repos/Erethon/Kippo-ansible',
'https://api.github.com/repos/HewlettPackard/Docker-SimpliVity',
'https://api.github.com/repos/liangshan/drill-ansible',
'https://api.github.com/repos/f5devcentral/f5-tmsh2iapp',
'https://api.github.com/repos/LinuxArchitects/Ansible-VMware-vRealize-Automation',
'https://api.github.com/repos/redhat-cop/ansible-middleware-playbooks',
'https://api.github.com/repos/surfuga/elkpi',
'https://api.github.com/repos/gbraad/ansible-playbook-kubernetes',
'https://api.github.com/repos/pcuzner/ceph-iscsi-ansible',
'https://api.github.com/repos/lizhitao0923/ansible-hadoop',
'https://api.github.com/repos/nd4pa/homesuite-ansible',
'https://api.github.com/repos/vincentvdk/ansible_pb_opennebula',
'https://api.github.com/repos/libersoft/ansible-alfresco',
'https://api.github.com/repos/sergevs/ansible-serviced-zenoss',
'https://api.github.com/repos/skippbox/ansible-cloudstack',
'https://api.github.com/repos/virtualelephant/vsphere-sddc',
'https://api.github.com/repos/torian/ansible-elb-deploy',
'https://api.github.com/repos/Bahmni/bahmni-playbooks',
'https://api.github.com/repos/oguya/ansible-ckan',
'https://api.github.com/repos/dell/openshift-container-architecture',
'https://api.github.com/repos/siamaksade/openshift-demos-ansible',
'https://api.github.com/repos/rackerlabs/ansible-dse',
'https://api.github.com/repos/jasodeep/ansible-lamp-stack-playbook',
'https://api.github.com/repos/nuagenetworks/nuage-openstack-ansible',
'https://api.github.com/repos/cedaro/ansible-deploy',
'https://api.github.com/repos/kermat/linbit-ansible',
'https://api.github.com/repos/ing-bank/ansible-selenium-grid',
'https://api.github.com/repos/v1k0d3n/tower-openstack',
'https://api.github.com/repos/puntonim/ansible-biostar',
'https://api.github.com/repos/alens/Ansible-LikewiseOpen',
'https://api.github.com/repos/wise2c-devops/harbor-ha',
'https://api.github.com/repos/openstack/tripleo-ansible',
'https://api.github.com/repos/bevuta/ansible-deploy-user',
'https://api.github.com/repos/georchestra/ansible',
'https://api.github.com/repos/radondb/radondb-ansible',
'https://api.github.com/repos/smiller171/Ansible-CloudWatch',
'https://api.github.com/repos/adrahon/ansible-docker-ucp',
'https://api.github.com/repos/carlosedp/openshift-playbooks',
'https://api.github.com/repos/danitfk/Cluster-ELK-Ansible',
'https://api.github.com/repos/rodo/ansible-tsung',
'https://api.github.com/repos/pescobar/ansible-easybuild-lmod',
'https://api.github.com/repos/mmgaggle/bd',
'https://api.github.com/repos/rasputnik/ansible-confluent',
'https://api.github.com/repos/johandahlberg/ansible_spark_openstack',
'https://api.github.com/repos/marco-santamaria/django-ansible-deploy',
'https://api.github.com/repos/hotta/ansible-centos7',
'https://api.github.com/repos/aknot242/ansible-uber-demo',
'https://api.github.com/repos/pattu777/Ansible-Django',
'https://api.github.com/repos/smowden/meteor-ansible',
'https://api.github.com/repos/jlaska/ansible-rhevm-all-in-one',
'https://api.github.com/repos/kisamoto/dancible',
'https://api.github.com/repos/jpmondet/Fully-Automated-BGP-fabric',
'https://api.github.com/repos/shiftctrlspace/library',
'https://api.github.com/repos/jgrowl/ansible-playbook-artifactory',
'https://api.github.com/repos/projectatomic/ansible-osbs',
'https://api.github.com/repos/wikitops/ansible_tableau',
'https://api.github.com/repos/Alir3z4/ansible-suricata',
'https://api.github.com/repos/oleg-fiksel/ansible-taskd',
'https://api.github.com/repos/shyamjos/Ansible-mysql-galera-cluster',
'https://api.github.com/repos/bocharsky-bw/vagrant-ansible-docker',
'https://api.github.com/repos/stuhli/dfirtrack_ansible',
'https://api.github.com/repos/wadeschulz/ansible-docker-swarm-tls',
'https://api.github.com/repos/jonghall/ibmcloud-terraform-vpc',
'https://api.github.com/repos/gbunt/cloudian-ansible-baremetal',
'https://api.github.com/repos/danitfk/Ansible-Postfix-MTA',
'https://api.github.com/repos/vscale/ansible-playbooks',
'https://api.github.com/repos/deconst/deploy',
'https://api.github.com/repos/websauna/websauna.ansible',
'https://api.github.com/repos/CaliOpen/caliopen-ansible',
'https://api.github.com/repos/dcritch/ansible-ospdbs',
'https://api.github.com/repos/devjatkin/stackforce-ansible',
'https://api.github.com/repos/d1vious/splunkconf2015-demo',
'https://api.github.com/repos/nickmaccarthy/ansible-kubernetes-deployment-sample',
'https://api.github.com/repos/chrislaskey/ansible-deploy',
'https://api.github.com/repos/lmacken/suricata-ansible',
'https://api.github.com/repos/rosskukulinski/ghost-ansible',
'https://api.github.com/repos/danitfk/Ansible-Asterisk-Proxmox-LXC',
'https://api.github.com/repos/admin-ch/IEW_Toolchain_Ansible',
'https://api.github.com/repos/ndlib/marble-blueprints',
'https://api.github.com/repos/ubuntunet/eduroam_radius',
'https://api.github.com/repos/eucalyptus/playbook',
'https://api.github.com/repos/docker-production-aws/microtrader-deploy',
'https://api.github.com/repos/pescobar/ansible-opennebula',
'https://api.github.com/repos/jonjozwiak/ansible-optools',
'https://api.github.com/repos/mikefromit/ansible-mayan-edms',
'https://api.github.com/repos/yutannihilation/ansible-playbook-r',
'https://api.github.com/repos/ajoyoommen/django-ansible',
'https://api.github.com/repos/DanielFroehlich/stormshift',
'https://api.github.com/repos/sw360cab/ansible-slb-tomcat',
'https://api.github.com/repos/sunx/koji-ansible',
'https://api.github.com/repos/candidtim/cookiecutter-flask-ansible',
'https://api.github.com/repos/jpmondet/Fully-Automated-K8s-deployment',
'https://api.github.com/repos/jairojunior/wildfly-ha-tcpgossip-vagrant-puppet',
'https://api.github.com/repos/lewandom/k8s-ansible-playbooks-demo',
'https://api.github.com/repos/auth-it-center/grid-services-deployment',
'https://api.github.com/repos/ARGOeu/argo-ansible',
'https://api.github.com/repos/docker-production-aws/cloudformation-resources',
'https://api.github.com/repos/Joeskyyy/redis_cluster',
'https://api.github.com/repos/rciam/rciam-deploy',
'https://api.github.com/repos/von8/wordpress-ansible',
'https://api.github.com/repos/rerorero/vultr-k8s-playbook',
'https://api.github.com/repos/arocki7/terraform-ansible',
'https://api.github.com/repos/VirtusLab/mesos-on-vagrant',
'https://api.github.com/repos/UnitedPlanet/intrexx-cloud-playbooks',
'https://api.github.com/repos/beardon/ansible-tower-setup',
'https://api.github.com/repos/Kami/ansible-memcached',
'https://api.github.com/repos/orrsella/mah-server',
'https://api.github.com/repos/redhat-cip/dci-infra',
'https://api.github.com/repos/n3x77/ansible_timesketch',
'https://api.github.com/repos/marlof/ScORCH',
'https://api.github.com/repos/kermat/linstor-ansible',
'https://api.github.com/repos/webmat/devopsmtl.com',
'https://api.github.com/repos/jorgemanrubia/ansible-rails-toolkit',
'https://api.github.com/repos/quocvu/postgresql-ansible',
'https://api.github.com/repos/wikitops/ansible_kubernetes_argocd',
'https://api.github.com/repos/rocketpod/wagtail-freebsd10.1-ansible',
'https://api.github.com/repos/h2suzuki/ansible-lxr-nupic.core',
'https://api.github.com/repos/sap-commerce-tools/ccv1-ansible',
'https://api.github.com/repos/robparrott/openstack-deploy',
'https://api.github.com/repos/packit-service/deployment',
'https://api.github.com/repos/ansibleplaybookbundle/keycloak-apb',
'https://api.github.com/repos/docker-production-aws/network-resources',
'https://api.github.com/repos/docker-production-aws/ecr-resources',
'https://api.github.com/repos/ideascube/ansiblecube',
'https://api.github.com/repos/adfinis-sygroup/mirror-ansible',
'https://api.github.com/repos/mozilla/mig-deploy',
'https://api.github.com/repos/f5devcentral/f5-openstack-ansible',
'https://api.github.com/repos/LewisW/ansible-symfony-playbook',
'https://api.github.com/repos/Minitex/ls-ansible-deploy',
'https://api.github.com/repos/jakubigla/ansible-ec2-wordpress',
'https://api.github.com/repos/syotani/deploy-vsphere-cluster',
'https://api.github.com/repos/ESGF/esgf-ansible',
'https://api.github.com/repos/SC5/serverless-deployment-ansible',
'https://api.github.com/repos/inonit/ansible-elk',
'https://api.github.com/repos/dymurray/ethereum-console-apb',
'https://api.github.com/repos/RHsyseng/ocp-on-synergy',
'https://api.github.com/repos/RedHatGov/Instant-Demo',
'https://api.github.com/repos/OpenSRP/playbooks',
'https://api.github.com/repos/mstrisoline/ruby-builder',
'https://api.github.com/repos/zestedesavoir/ansible-zestedesavoir',
'https://api.github.com/repos/LibriVox/librivox-ansible',
'https://api.github.com/repos/coderefinery/gitlab-openstack-deploy',
'https://api.github.com/repos/misaakidis/mazizone-ansible',
'https://api.github.com/repos/rossmcdonald/influxdb-ansible',
'https://api.github.com/repos/srgl/ansible-rails',
'https://api.github.com/repos/jgrowl/ansible-playbook-ssl-certs',
'https://api.github.com/repos/ivan1993spb/snake-ansible',
'https://api.github.com/repos/DigitalPebble/ansible-storm',
'https://api.github.com/repos/rynffoll/envy',
'https://api.github.com/repos/jgrowl/ansible-playbook-sickbeard',
'https://api.github.com/repos/cohenjo/DB_Ansible',
'https://api.github.com/repos/jgrowl/ansible-playbook-jenkins',
'https://api.github.com/repos/jgrowl/ansible-playbook-sickbeard',
'https://api.github.com/repos/stalinstepin/NoMachine',
'https://api.github.com/repos/home-cluster/tower-apb',
'https://api.github.com/repos/robbintt/dotfiles',
'https://api.github.com/repos/jimrigsbee/coolstore-microservices-ansible',
'https://api.github.com/repos/oracle-quickstart/oci-apex',
'https://api.github.com/repos/ansible-meetup-dresden/ansible-play-srv_httpd',
'https://api.github.com/repos/mstrisoline/ansible-logstash-play',
'https://api.github.com/repos/SecurityInsanity/ansible-spigot',
'https://api.github.com/repos/talaniz/ansible-pelican',
'https://api.github.com/repos/cyverse/ds-playbooks',
'https://api.github.com/repos/dirtyonekanobi/pb_create_tower_deploykey',
'https://api.github.com/repos/acefei/ace-playbook',
'https://api.github.com/repos/12beseuahmad/ansible_single_node_openstack',
'https://api.github.com/repos/pelgrim/ddns_ansible_playbook',
'https://api.github.com/repos/rackeric/destiny',
'https://api.github.com/repos/waammar/ansible-elastic-stack',
'https://api.github.com/repos/invicnaper/foreman-ansible-postgres',
'https://api.github.com/repos/wikitops/ansible_nexus',
'https://api.github.com/repos/pjbriggs/ansible-palfinder-galaxy',
'https://api.github.com/repos/nccurry/openshift-kvm-lab',
'https://api.github.com/repos/mbauer599/Ansible-SSHKeys',
'https://api.github.com/repos/samsulmaarif/ansible-deploy-laravel',
'https://api.github.com/repos/jmo808/azure-oracle-db-prod',
'https://api.github.com/repos/noisetor/monitoring',
'https://api.github.com/repos/yungshun317/ansible-k8s-helm-spark',
'https://api.github.com/repos/linkbynet/openstack-ansible-wordpressha',
'https://api.github.com/repos/Qualys-Public/Cloud_Agent_Ansible',
'https://api.github.com/repos/nwiizo/openfaas-on-conoha',
'https://api.github.com/repos/cloudhotspot/ansible-csr1000v-playbook',
'https://api.github.com/repos/erickrheinrich/aws-css-srcds',
'https://api.github.com/repos/wikitops/ansible_gitlab_runner',
'https://api.github.com/repos/dmytro-lytvyn/dp-ansible-roles',
'https://api.github.com/repos/eggshell/replay_pipeline',
'https://api.github.com/repos/arnaudblancher/ansible-role-docker_provisionning',
'https://api.github.com/repos/scigility/hadoop-ops',
'https://api.github.com/repos/IslamHeggy/kubernetes-pod-deployment-aws',
'https://api.github.com/repos/itrobertson/ELK-Proxy-Ingest',
'https://api.github.com/repos/pyvideo/richard-ansible',
'https://api.github.com/repos/markramach/ansible-kubernetes-playbooks',
'https://api.github.com/repos/Semmle/lgtm-ansible-example',
'https://api.github.com/repos/docker-production-aws/microtrader-pipeline',
'https://api.github.com/repos/navidpaya/ansible-scout',
'https://api.github.com/repos/SantanderMetGroup/ansible-thredds-cluster',
'https://api.github.com/repos/docker-production-aws/proxy-resources',
'https://api.github.com/repos/yatesr/playbook-etherpad',
'https://api.github.com/repos/dimaskiddo/ansible-mongo-percona',
'https://api.github.com/repos/rh-messaging-qe/ansible-broker-clusters',
'https://api.github.com/repos/silentninja/ansible-vnc',
'https://api.github.com/repos/rletters/ansible-rletters-2',
'https://api.github.com/repos/nkwd/ansible-playbooks',
'https://api.github.com/repos/albertomurillo/ansible-openstack',
'https://api.github.com/repos/capyroto/foremansible',
'https://api.github.com/repos/periodo/periodo-deployment',
'https://api.github.com/repos/woody1983/Ansible-Webserver',
'https://api.github.com/repos/oatakan/ansible-dotnet-music-store-app',
'https://api.github.com/repos/jgrowl/ansible-playbook-ruby-from-src',
'https://api.github.com/repos/italia/docs-italia-deploy-scripts',
'https://api.github.com/repos/EMC-Underground/terraform_dockerswarm',
'https://api.github.com/repos/Prophidys/ansible-designate',
'https://api.github.com/repos/user-cont/bots-deployment',
'https://api.github.com/repos/geosolutions-it/geoserver-playbook',
'https://api.github.com/repos/pulp/pulp-infra-ansible',
'https://api.github.com/repos/ekeih/hetzner-deployment',
'https://api.github.com/repos/YPCrumble/ansible-react-server-rendered',
'https://api.github.com/repos/lord-kyron/flawless-wordpress',
'https://api.github.com/repos/aanisimov/openstf-ansible',
'https://api.github.com/repos/gouwschristo/moodle',
'https://api.github.com/repos/SergK/ansible-gerrit',
'https://api.github.com/repos/oatakan/splunk-ansible',
'https://api.github.com/repos/rosskukulinski/ansible-ghost',
'https://api.github.com/repos/alanorth/ansible-dspace',
'https://api.github.com/repos/joseillan/stackvdi_playbook',
'https://api.github.com/repos/alvistack/ansible-collection-kubernetes',
'https://api.github.com/repos/jmferrer/ansible-elasticsearch',
'https://api.github.com/repos/Christo-Stoyanov/lynis-ansible',
'https://api.github.com/repos/dron23/SensoricNet-ansible',
'https://api.github.com/repos/NickYadance/ansible-spring-boot-gradle',
'https://api.github.com/repos/rightsstatements/rights-deploy',
'https://api.github.com/repos/antlamont/ansible-securityonion',
'https://api.github.com/repos/Greg-Boggs/ansible-deploy',
'https://api.github.com/repos/mylesjao/ansible',
'https://api.github.com/repos/sergeytsivin/example-ansible',
'https://api.github.com/repos/hexaaproject/ansible-hexaa',
'https://api.github.com/repos/tfrce/ansible-geoip',
'https://api.github.com/repos/superxor/ansible-proxmox-hetzner',
'https://api.github.com/repos/jenciso/kubernetes-cluster',
'https://api.github.com/repos/akerl/deploy-wireguard-server',
'https://api.github.com/repos/jonatasbaldin/pc-deploy',
'https://api.github.com/repos/tfrce/ansible-geoip',
'https://api.github.com/repos/superxor/ansible-proxmox-hetzner',
'https://api.github.com/repos/jgrowl/ansible-playbook-krb',
'https://api.github.com/repos/metucclub/dmoj-playbook',
'https://api.github.com/repos/jenciso/kubernetes-cluster',
'https://api.github.com/repos/akerl/deploy-wireguard-server',
'https://api.github.com/repos/jonatasbaldin/pc-deploy',
'https://api.github.com/repos/romanofski/junglebuild',
'https://api.github.com/repos/jgrowl/ansible-playbook-nginx',
'https://api.github.com/repos/hmsrc/ddn-exascaler',
'https://api.github.com/repos/gsr-shanks/adb-deploy',
'https://api.github.com/repos/openwide-java/owsi-core-ansible',
'https://api.github.com/repos/KaiserSoft/ansible-SSH-Key-Deploy',
'https://api.github.com/repos/sakaal/admin_client_ansible',
'https://api.github.com/repos/adityak2190/sitedeploy',
'https://api.github.com/repos/insanity54/sab-deploy',
'https://api.github.com/repos/GenBrg/spark-deployment',
'https://api.github.com/repos/latouchek/openstack-ansible-postdeploy',
'https://api.github.com/repos/StanfordLegion/gitlab-runner-deploy',
'https://api.github.com/repos/mehikmat/hdp2-ansible',
'https://api.github.com/repos/att-esst/osa-prep',
'https://api.github.com/repos/chromium58/ansible-kubernetes',
'https://api.github.com/repos/olimatis/otif-ansible',
'https://api.github.com/repos/wikitops/ansible_telegraf',
'https://api.github.com/repos/jgrowl/ansible-playbook-auth',
'https://api.github.com/repos/v13abh/ansible-fedora24-config',
'https://api.github.com/repos/paviliondev/pavilion-ansible',
'https://api.github.com/repos/lyrasis/deploy-monitoring',
'https://api.github.com/repos/XCSoar/xcsoar-mapgen-ansible',
'https://api.github.com/repos/jgrowl/ansible-playbook-nfs-client',
'https://api.github.com/repos/yungshun317/ansible-k8s-kafka',
'https://api.github.com/repos/yungshun317/ansible-k8s-cassandra',
'https://api.github.com/repos/oigarash-cisco/ansible_cisco_cms',
'https://api.github.com/repos/tri2sing/AnsibleMongoReplicaSetLXC',
'https://api.github.com/repos/naveen-vijay/ansible-deploy-lambda-serverless-snippets',
'https://api.github.com/repos/jgrowl/ansible-playbook-nfs-client',
'https://api.github.com/repos/coreyerickson/core-kubernetes',
'https://api.github.com/repos/mcktr/ansible-icinga2',
'https://api.github.com/repos/fafadiatech/ft-ansible-playbook',
'https://api.github.com/repos/LINBIT/linstor-ansible',
'https://api.github.com/repos/agaveplatform/deployer',
'https://api.github.com/repos/maxbrunet/ansidot',
'https://api.github.com/repos/Southern-Exposure-Seed-Exchange/Website-Ansible-Playbook',
'https://api.github.com/repos/lyrasis/deploy-monitoring',
'https://api.github.com/repos/XCSoar/xcsoar-mapgen-ansible',
'https://api.github.com/repos/praveenkumar/jenkins-ansible',
'https://api.github.com/repos/enredacoop/ansible-consul',
'https://api.github.com/repos/wikitops/ansible_pip',
'https://api.github.com/repos/wikitops/ansible_docker',
'https://api.github.com/repos/patrickod/noisebridge.social',
'https://api.github.com/repos/lugorguk/ansible-playbook',
'https://api.github.com/repos/LorbusChris/openshift-acme-installer',
'https://api.github.com/repos/nwiizo/kubernetes-on-conoha',
'https://api.github.com/repos/arashkaffamanesh/ansible-k3s',
'https://api.github.com/repos/zalari/ansible-deploy-docker-compose',
'https://api.github.com/repos/tomascohen/ansible-dspace',
'https://api.github.com/repos/ecostanzi/ansible-jhipster-demo',
'https://api.github.com/repos/wikitops/ansible_chronograf',
'https://api.github.com/repos/kduerr/ansible-hpe-spp',
'https://api.github.com/repos/aml-development/ozp-ansible-playbooks',
'https://api.github.com/repos/tomaskrizek/resolver-dns-tls-deploy',
'https://api.github.com/repos/fritz-c/refwd-deploy',
'https://api.github.com/repos/ccollicutt/vcl_ansible',
'https://api.github.com/repos/yungshun317/ansible-k8s-spark',
'https://api.github.com/repos/dimitris-sweagle/sweagle-ansible',
'https://api.github.com/repos/bibliosansfrontieres/ideascube-deploy',
'https://api.github.com/repos/sacharya/ansible-cassandra',
'https://api.github.com/repos/osic/osic-qe-ci-ansible-playbooks',
'https://api.github.com/repos/nwiizo/knative-on-conoha',
'https://api.github.com/repos/rynldtbuen/cumulus-evpn-vxlan-ansible',
'https://api.github.com/repos/sunilfernandes/nexus-openshift-ansible',
'https://api.github.com/repos/wehappyfew/Ansible-Playbooks',
'https://api.github.com/repos/grizzthedj/ansinetes',
'https://api.github.com/repos/bird-house/ansible-wps-playbook',
'https://api.github.com/repos/bigchaindb/bigchaindb-node-ansible',
'https://api.github.com/repos/kengraf/neccdc2018local',
'https://api.github.com/repos/brainstorm/ansible-rackspace',
'https://api.github.com/repos/danitfk/Ansible_Kubernetes-Cluster-CentOS',
'https://api.github.com/repos/linuxshark/aws-automation-training',
'https://api.github.com/repos/germanium-git/nsxvansible',
'https://api.github.com/repos/citrix/citrix-ansible-aws',
'https://api.github.com/repos/openhie/ansible-openhim',
'https://api.github.com/repos/erinish/dev_containers',
'https://api.github.com/repos/rimiti/ansible-debian-vagrant',
'https://api.github.com/repos/pivotal-jack-moon/gpfarmer',
'https://api.github.com/repos/coreybobco/ansible-setspy',
'https://api.github.com/repos/open-source-affiliate/3rd-party-retargeter-deploy',
'https://api.github.com/repos/victorhqc/ansible-web',
'https://api.github.com/repos/helenapoleri/ghost-deployment',
'https://api.github.com/repos/yan0s/ansible-openstack',
'https://api.github.com/repos/waheedi/aws-springboot-ansible',
'https://api.github.com/repos/ngrinkevich/ansible-geodjango-stack',
'https://api.github.com/repos/nccurry/ocp4-windows',
'https://api.github.com/repos/danitfk/nginxproxy-keepalived',
'https://api.github.com/repos/openhie/ansible-openhim',
'https://api.github.com/repos/erinish/dev_containers',
'https://api.github.com/repos/rimiti/ansible-debian-vagrant',
'https://api.github.com/repos/pivotal-jack-moon/gpfarmer',
'https://api.github.com/repos/open-source-affiliate/3rd-party-retargeter-deploy',
'https://api.github.com/repos/victorhqc/ansible-web',
'https://api.github.com/repos/helenapoleri/ghost-deployment',
'https://api.github.com/repos/openhie/ansible-openempi',
'https://api.github.com/repos/tommytomatoe/ansible-playbooks',
'https://api.github.com/repos/brianannis/pogoprint',
'https://api.github.com/repos/mkosterin/owncloud_gce',
'https://api.github.com/repos/jascott1/k8s4ic',
'https://api.github.com/repos/pridetechdesign/letsencrypt_wildcards',
'https://api.github.com/repos/syedsaadahmed/Ansible-Playbook-Samples',
'https://api.github.com/repos/mcred/Ansible-Project-Deploy',
'https://api.github.com/repos/misho-kr/ansible-cloud-playbooks',
'https://api.github.com/repos/debalance/ansible-playbook-jabber.rwth-aachen.de',
'https://api.github.com/repos/amcaar/ansible-playbook-hybrid-clusters',
'https://api.github.com/repos/CSCfi/pouta-openshift-cluster',
'https://api.github.com/repos/yard-turkey/ansible-cloud-deploy',
'https://api.github.com/repos/nccurry/openshift-4-libvirt',
'https://api.github.com/repos/home-cluster/ceph-apb',
'https://api.github.com/repos/wikitops/ansible_artifactory',
'https://api.github.com/repos/chris7444/csi',
'https://api.github.com/repos/sakaal/continuous_delivery_ansible',
'https://api.github.com/repos/LapaLabs/symfony-deploy',
'https://api.github.com/repos/wikitops/ansible_artifactory',
'https://api.github.com/repos/chris7444/csi',
'https://api.github.com/repos/mtarking/cisco-vts',
'https://api.github.com/repos/jonalma/Vagrant_Ansible',
'https://api.github.com/repos/tripl3inf/WordPlay',
'https://api.github.com/repos/CentOS/sig-core-QA_harness_ansible',
'https://api.github.com/repos/g-div/ansible-nginx-multisite',
'https://api.github.com/repos/masenocturnal/ansible-lets_encrypt',
'https://api.github.com/repos/slaffer-au/vx_vagrant_ansible_demo',
'https://api.github.com/repos/arvindtelharkar1992/Automated-Server-Provisioning',
'https://api.github.com/repos/ndlib/eaasi-blueprints',
'https://api.github.com/repos/opi/ansible',
'https://api.github.com/repos/Harijith-R/Flask-App-Ansible',
'https://api.github.com/repos/my0373/ansible_PCI_DSS_V3_remediation',
'https://api.github.com/repos/provocon/coremedia-node-preparation',
'https://api.github.com/repos/prasanjit-/ansible-demo',
'https://api.github.com/repos/galaxyproject/ansible-cloudlaunch',
'https://api.github.com/repos/TkTech/ckan.playbook',
'https://api.github.com/repos/asascience-open/ansible-playbooks',
'https://api.github.com/repos/shakedlokits/ansible-sonar-deployment',
'https://api.github.com/repos/jeffsteinmetz/ansible-hadoop',
'https://api.github.com/repos/coreyerickson/ansible-owncloud',
'https://api.github.com/repos/wiggzz/ansible-dsnode',
'https://api.github.com/repos/prasanjit-/pluggable-terraform-in-ansible',
'https://api.github.com/repos/AppScale/ats-deploy',
'https://api.github.com/repos/gnarula/eden_playbook',
'https://api.github.com/repos/sloopstash/kickstart-ansible',
'https://api.github.com/repos/mredar/aspace_deploy',
'https://api.github.com/repos/jgrowl/ansible-playbook-sssd',
'https://api.github.com/repos/b-com/ansible-monasca',
'https://api.github.com/repos/jgrowl/ansible-playbook-sssd',
'https://api.github.com/repos/cedadev/esgf-slcs-server-playbook',
'https://api.github.com/repos/b-com/ansible-monasca',
'https://api.github.com/repos/saisrinivaskondreddy/ansible_webappdelpoy_mysql_tomcat',
'https://api.github.com/repos/CSCfi/pouta-ansible-cluster',
'https://api.github.com/repos/blallau/cluster-ansible-aio',
'https://api.github.com/repos/ironbars/ansible-bigtop',
'https://api.github.com/repos/mescanef/ansible-yum-cron',
'https://api.github.com/repos/asghaier/dkansible',
'https://api.github.com/repos/abhishekpolavarpu/ansibletest',
'https://api.github.com/repos/fdivita/ocp-deployment',
'https://api.github.com/repos/mimacom/docker-ansible',
'https://api.github.com/repos/jmcvetta/ansible-control-server',
'https://api.github.com/repos/ndalbroi/anservice-playbooks',
'https://api.github.com/repos/InnovaLangues/self-deploy',
'https://api.github.com/repos/sedlersan/test-task',
'https://api.github.com/repos/RafaelRuales/ansible',
'https://api.github.com/repos/riotousliving/rlfarm-playbook',
'https://api.github.com/repos/StLuke/ovirt-metrics-store',
'https://api.github.com/repos/aptituz/ansible-raspbee',
'https://api.github.com/repos/vakanto/ansible-prometheus',
'https://api.github.com/repos/amaczuga/staytus-deploy',
'https://api.github.com/repos/ur-technology/ur-ansible',
'https://api.github.com/repos/UMD-DCIC/ciber-elasticsearch',
'https://api.github.com/repos/quanvuminh/splunk-deployment-playbook',
'https://api.github.com/repos/CT-Data-Collaborative/ctdata-ckan-ansible',
'https://api.github.com/repos/SCORE1387/kube-ansible',
'https://api.github.com/repos/mutovis/deploy',
'https://api.github.com/repos/renci-unc/ansible-pycsw',
'https://api.github.com/repos/modelbrouwers/ansible',
'https://api.github.com/repos/bsao/ansible-aws',
'https://api.github.com/repos/lvlvwbln/rails-ansible-playbook',
'https://api.github.com/repos/MarioPerezEsteso/ansible-deploy',
'https://api.github.com/repos/matz0r/ansible-mzlnet',
'https://api.github.com/repos/rlukin/ansible-ctfd',
'https://api.github.com/repos/jonhadfield/ansible-kibana',
'https://api.github.com/repos/DrMartiner/django-playbooks',
'https://api.github.com/repos/stuhol/Ansible-Bro-IDS',
'https://api.github.com/repos/jonhadfield/ansible-nginx',
'https://api.github.com/repos/andymcc/ansible-lxc-rpc-origi2',
'https://api.github.com/repos/irl/direwolf-ansible',
'https://api.github.com/repos/wuenhouse/Ansible',
'https://api.github.com/repos/CustomPoint/ansible-minikube',
'https://api.github.com/repos/merchantly/ansible',
'https://api.github.com/repos/LukeGaudreau/playbook',
'https://api.github.com/repos/Ninroot/question2answer-playbook',
'https://api.github.com/repos/krish512/ansible-playbooks',
'https://api.github.com/repos/trailofbits/mc-ansible',
'https://api.github.com/repos/playniuniu/ansible-weblogic-deploy',
'https://api.github.com/repos/ryanbreed/paystub-playbooks',
'https://api.github.com/repos/libre-forge/ebla',
'https://api.github.com/repos/frumiousbandersnatch/sobrieti-ansible',
'https://api.github.com/repos/gorilych/oap-ansible',
'https://api.github.com/repos/jesmigel/ansible_kube_cluster',
'https://api.github.com/repos/jonhadfield/ansible-redis',
'https://api.github.com/repos/j3k0/ganomede-playbooks',
'https://api.github.com/repos/zxslinux/deploy',
'https://api.github.com/repos/knikolla/ansible-haas',
'https://api.github.com/repos/tsheth/DSA-Ansible',
'https://api.github.com/repos/Midori-ch/Ansible-EFK',
'https://api.github.com/repos/ragingbal/ansible-prestashop',
'https://api.github.com/repos/jbmorley/breakin-playbook',
'https://api.github.com/repos/cobaltjacket/AvA',
'https://api.github.com/repos/craigforr/awx-playbook-examples',
'https://api.github.com/repos/aminueza/ansible-kube',
'https://api.github.com/repos/wikitops/ansible_awx',
'https://api.github.com/repos/varmenise/ansible-petclinic-playbook',
'https://api.github.com/repos/voycey/cakephp-ansible',
'https://api.github.com/repos/alekseydemidov/ostack-deploy',
'https://api.github.com/repos/SEDISH/SEDISH-playbooks',
'https://api.github.com/repos/alandry5925/ScriptLab',
'https://api.github.com/repos/FreeHealth/ansible',
'https://api.github.com/repos/obscuritylabs/cuckoo-playbook',
'https://api.github.com/repos/adhils/TW_MediaWiki',
'https://api.github.com/repos/rgreisemer/RcElkAnsible',
'https://api.github.com/repos/medneta/ansible',
'https://api.github.com/repos/kwikiel/playbooks',
'https://api.github.com/repos/UCL/ansible-fludetector2',
'https://api.github.com/repos/mlgim/vSphere-DemoLab',
'https://api.github.com/repos/edgargp/ansiblebook',
'https://api.github.com/repos/CorfuDB/CorfuDB-Ansible',
'https://api.github.com/repos/erikperkins/ansible',
'https://api.github.com/repos/AMRUTA-BANDHU-CHAUDHURY/kubernetes-and-ansible',
'https://api.github.com/repos/flover97/hadoop-ansible',
'https://api.github.com/repos/modassarrana/KnativeApp',
'https://api.github.com/repos/shanesveller/ansible-vps-provisioner',
'https://api.github.com/repos/belminf/ansible-aws-hadoop',
'https://api.github.com/repos/CaliOpen/deploy-alpha',
'https://api.github.com/repos/cabdev/Playbooks',
'https://api.github.com/repos/omkar-dsd/KitBoard',
'https://api.github.com/repos/cabdev/Playbooks',
'https://api.github.com/repos/shanesveller/ansible-vps-provisioner',
'https://api.github.com/repos/hugoatease/ansible-playbook',
'https://api.github.com/repos/victorhqc/nodejs-ansible',
'https://api.github.com/repos/deetoo/AnsibleAnywhere',
'https://api.github.com/repos/InsaLan/VPNator',
'https://api.github.com/repos/sumaris-net/sumaris-ansible',
'https://api.github.com/repos/yatesr/playbook-server-deploy',
'https://api.github.com/repos/stellar-fox/ansible-playbooks',
'https://api.github.com/repos/RapidIE/shuttle',
'https://api.github.com/repos/akanda/astara-openstack-ansible',
'https://api.github.com/repos/UH-CI/ansible-owncloud',
'https://api.github.com/repos/ktarasyuk/meanio_ansible',
'https://api.github.com/repos/MichaelVL/openstack-packstack-ansible',
'https://api.github.com/repos/sheeshmohsin/ansible_playbook_template_django',
'https://api.github.com/repos/stackhpc/sib-ceph-ansible',
'https://api.github.com/repos/srwiser/wordpress-ansible',
'https://api.github.com/repos/eve-basil/deploy',
'https://api.github.com/repos/hkage/django-ansible',
'https://api.github.com/repos/Pypular/deployment',
'https://api.github.com/repos/hgdeoro/ansible-hadoop-cluster',
'https://api.github.com/repos/brusnigin/env-deploy',
'https://api.github.com/repos/rnusser/ansibletask',
'https://api.github.com/repos/AbrahamArellano/redhat_amq7_ansible_playbook',
'https://api.github.com/repos/j4jewel/ansible-deploying-ec2',
'https://api.github.com/repos/DecipherNow/ansible-playbooks',
'https://api.github.com/repos/antrusd/ansible-wildfly-windows',
'https://api.github.com/repos/gferandelle/ansible-playbooks-dcm4chee',
'https://api.github.com/repos/souenzzo/tsuru-deployer',
'https://api.github.com/repos/watchpoint-io/watchpoint-ansible',
'https://api.github.com/repos/marcosflobo/ansible-kubernetes',
'https://api.github.com/repos/Exchizz/ansible-dockerswarm',
'https://api.github.com/repos/CSCfi/pebbles-deploy',
'https://api.github.com/repos/openmaraude/APITaxi_deploy',
'https://api.github.com/repos/smeier00/ansible-osad-aio',
'https://api.github.com/repos/zastari/ansible-mysql-topologist',
'https://api.github.com/repos/arrfab/ansible-playbooks-opennebula',
'https://api.github.com/repos/patrickmslatteryvt/ansible-deploy-test',
'https://api.github.com/repos/petrikoz/wormhole',
'https://api.github.com/repos/angelosanramon/ansible-coreos-kubernetes-playbook',
'https://api.github.com/repos/4pisky/4pisky-cluster-config',
'https://api.github.com/repos/lozuwa/deployment-poc',
'https://api.github.com/repos/mathbe/ansible-lamp',
'https://api.github.com/repos/jrhe/ansible-ghost',
'https://api.github.com/repos/dratushnyy/ansible-cloudpulse',
'https://api.github.com/repos/dasrohr/omni_converter_deploy',
'https://api.github.com/repos/zhengyangtean/k8deploy',
'https://api.github.com/repos/rletters/ansible',
'https://api.github.com/repos/Xennis/xenniswiki-deployment-script',
'https://api.github.com/repos/hfolguera/deploy-kubernetes-cluster',
'https://api.github.com/repos/ozorest/ansible-nginx-aws',
'https://api.github.com/repos/hernando-garcia/ansible',
'https://api.github.com/repos/rodo/citus-ansible',
'https://api.github.com/repos/ice3/deploy_machines',
'https://api.github.com/repos/arisath/Hardened-Tomcat-Ansible-Playbook',
'https://api.github.com/repos/CaliOpen/deploy-tools',
'https://api.github.com/repos/replicas-io/gs-deploy',
'https://api.github.com/repos/saisampathb/ansible-playbook',
'https://api.github.com/repos/chiganov/ansible_scripts',
'https://api.github.com/repos/jonhadfield/ansible-logstash-agent',
'https://api.github.com/repos/angelosanramon/ansible-coreos-kubernetes-playbook',
'https://api.github.com/repos/jrhe/ansible-ghost',
'https://api.github.com/repos/dratushnyy/ansible-cloudpulse',
'https://api.github.com/repos/dasrohr/omni_converter_deploy',
'https://api.github.com/repos/zhengyangtean/k8deploy',
'https://api.github.com/repos/rletters/ansible',
'https://api.github.com/repos/Xennis/xenniswiki-deployment-script',
'https://api.github.com/repos/hfolguera/deploy-kubernetes-cluster',
'https://api.github.com/repos/chiganov/ansible_scripts',
'https://api.github.com/repos/jonhadfield/ansible-logstash-agent',
'https://api.github.com/repos/bougie/ansible_jrdsagent',
'https://api.github.com/repos/arkavidia5/arkav-ansible-playbooks',
'https://api.github.com/repos/nemanjan00/ansible',
'https://api.github.com/repos/salmanaghayev/nextcloud-apache-amazon-linux2',
'https://api.github.com/repos/jenscobie/ansible-skeleton-service',
'https://api.github.com/repos/iamcaleberic/wireguard-ansible',
'https://api.github.com/repos/jeremybobbin/playbook',
'https://api.github.com/repos/heywoodlh/send-ansible',
'https://api.github.com/repos/ashishranjan1457/ansible-terraform-playbook-pipeline',
'https://api.github.com/repos/ozorest/ansible-nginx-aws',
'https://api.github.com/repos/hernando-garcia/ansible',
'https://api.github.com/repos/rodo/citus-ansible',
'https://api.github.com/repos/ice3/deploy_machines',
'https://api.github.com/repos/arisath/Hardened-Tomcat-Ansible-Playbook',
'https://api.github.com/repos/CaliOpen/deploy-tools',
'https://api.github.com/repos/replicas-io/gs-deploy',
'https://api.github.com/repos/saisampathb/ansible-playbook',
'https://api.github.com/repos/jgrowl/ansible-playbook-auth-windows',
'https://api.github.com/repos/niksilver/scaladeployment',
'https://api.github.com/repos/SergeyTsaplin/devpi-ansible-playbook',
'https://api.github.com/repos/prabhakarpujeri/ddn-exascaler',
'https://api.github.com/repos/drew9781/ansible-k8s',
'https://api.github.com/repos/alebeta90/mozilla-hubs-devops',
'https://api.github.com/repos/jyundt/oval-ansible',
'https://api.github.com/repos/nadirizr/hubot-deploy-ansible-docker',
'https://api.github.com/repos/thejaspm/ansibleOpenResty',
'https://api.github.com/repos/okbreathe/ansible-ubuntu',
'https://api.github.com/repos/orangle/mydeploy',
'https://api.github.com/repos/buzzbombnc/site_deployments',
'https://api.github.com/repos/Kookster310/dn42-node',
'https://api.github.com/repos/cespgoespoop/buildbot',
'https://api.github.com/repos/openecs/deployer',
'https://api.github.com/repos/spy86/ansible-apache-solr',
'https://api.github.com/repos/damienmas/ansible-deploy-vmware-vm',
'https://api.github.com/repos/pfe-asr-2014/ansible-playbook',
'https://api.github.com/repos/michaelkunc/fakerservice_deploy',
'https://api.github.com/repos/hos7ein/local-npm-ansible',
'https://api.github.com/repos/weeclemans/sas_playbooks',
'https://api.github.com/repos/supercoffee/nginx-playground',
'https://api.github.com/repos/YannMoisan/ansible-nginx',
'https://api.github.com/repos/lexibrent/min-dotfiles-deploy',
'https://api.github.com/repos/sundeepguraja/AwsVM',
'https://api.github.com/repos/zabbixfan/tomcatdeploy',
'https://api.github.com/repos/fernflower/ansible_django_steps',
'https://api.github.com/repos/rackerlabs/ansible-rift',
'https://api.github.com/repos/monty20python/ansible_playbooks',
'https://api.github.com/repos/coreybobco/ansible-textgen-apps',
'https://api.github.com/repos/utsushiiro/server-management',
'https://api.github.com/repos/graphite-server/ansible',
'https://api.github.com/repos/agstephens/prima-dmt-ansible',
'https://api.github.com/repos/baptistegh/deploy-neo4j-cluster',
'https://api.github.com/repos/okbreathe/ansible-ubuntu',
'https://api.github.com/repos/nadirizr/hubot-deploy-ansible-docker',
'https://api.github.com/repos/thejaspm/ansibleOpenResty',
'https://api.github.com/repos/orangle/mydeploy',
'https://api.github.com/repos/buzzbombnc/site_deployments',
'https://api.github.com/repos/Kookster310/dn42-node',
'https://api.github.com/repos/cespgoespoop/buildbot',
'https://api.github.com/repos/openecs/deployer',
'https://api.github.com/repos/spy86/ansible-apache-solr',
'https://api.github.com/repos/damienmas/ansible-deploy-vmware-vm',
'https://api.github.com/repos/prateek2408/AnsiblePlaybooks-OpenstackMitaka',
'https://api.github.com/repos/litwicki/ansible',
'https://api.github.com/repos/haxware/ansible-docker',
'https://api.github.com/repos/DasonYang/kubernetes-ansible-playbook',
'https://api.github.com/repos/reportportal/ansible-playbook',
'https://api.github.com/repos/BaobabLims/baobab-ansible',
'https://api.github.com/repos/diegoamc/ansible',
'https://api.github.com/repos/yo1frenchtoast/mcma-ansible',
'https://api.github.com/repos/igloo-project/igloo-ansible',
'https://api.github.com/repos/JohnPreston/eucalyptus-ansible-inventory-generator',
'https://api.github.com/repos/purplepalmdash/Ansible',
'https://api.github.com/repos/alamsyahho/ansible-lemp-examples',
'https://api.github.com/repos/carlosedp/openstack-ansible-playbooks',
'https://api.github.com/repos/sigdotcom/ansible-playbooks',
'https://api.github.com/repos/jmcleroy/cloudformsnetwork',
'https://api.github.com/repos/auth-it-center/egi-broker',
'https://api.github.com/repos/ajeet-rock1/K8_Ansible',
'https://api.github.com/repos/krisek/aci-utils',
'https://api.github.com/repos/kavaka123/todobackend-deploy',
'https://api.github.com/repos/zkarimov/apacheproject',
'https://api.github.com/repos/SimonBaeumer/dind-gitlab-runner-playbook',
'https://api.github.com/repos/Frizz925/ansible-squid-proxy',
'https://api.github.com/repos/haxware/ansible-haproxy',
'https://api.github.com/repos/pandora-auth-ros-pkg/deployment-scripts',
'https://api.github.com/repos/brewmajsters/ansible-skeleton',
'https://api.github.com/repos/osism/docker-kolla-ansible',
'https://api.github.com/repos/koslab/ansible-kibana',
'https://api.github.com/repos/mbach04/openshift_prep',
'https://api.github.com/repos/vibhorgoel25/wordpress-ansible',
'https://api.github.com/repos/Kiranmoh/devops-Ansible',
'https://api.github.com/repos/rodrigo-hissam/ansible-invoice-ninja',
'https://api.github.com/repos/andrew-klassen/hope_matters_server_deployment',
'https://api.github.com/repos/discopatrick/owncloud-ansible',
'https://api.github.com/repos/ZeroDeth/ansible-playbook',
'https://api.github.com/repos/osism/docker-ceph-ansible',
'https://api.github.com/repos/wikitops/ansible_ara',
'https://api.github.com/repos/tbeckham/cloud-playbook',
'https://api.github.com/repos/r3lik/scout',
'https://api.github.com/repos/samgclarke/ansible-flask-simple',
'https://api.github.com/repos/wasanthag/ansible_deploy_kvm',
'https://api.github.com/repos/lairdubois/lairdubois-ansible',
'https://api.github.com/repos/Phozbrav/ansible-flink-cluster',
'https://api.github.com/repos/troshenkov/ansible-monit',
'https://api.github.com/repos/wikitops/ansible_collectd',
'https://api.github.com/repos/wikitops/ansible_keycloak',
'https://api.github.com/repos/jgruber/f5-hot-ansible',
'https://api.github.com/repos/wikitops/ansible_mesos',
'https://api.github.com/repos/opticyclic/corda-ansible-deploy',
'https://api.github.com/repos/iMerica/pik3s',
'https://api.github.com/repos/SpenserJ/Ansible-Playbook-Apt-Cacher',
'https://api.github.com/repos/alxgomz/ansible-alfbm',
'https://api.github.com/repos/darvein/ansible-kubernetes',
'https://api.github.com/repos/jijisa/k8s_cent7',
'https://api.github.com/repos/alokpatra/Three_Tier_Application',
'https://api.github.com/repos/wikitops/ansible_haproxy',
'https://api.github.com/repos/AllenShi/kubeadm-ha-ansible',
'https://api.github.com/repos/dcna-io/kubernetes',
'https://api.github.com/repos/wikitops/ansible_pgadmin4',
'https://api.github.com/repos/kenmoini/fsw-workshop-provisioners',
'https://api.github.com/repos/githubixx/ansible-postfix-playbooks',
'https://api.github.com/repos/dmend/chamberlain',
'https://api.github.com/repos/bocharsky-bw/ansible-symfony-deploy',
'https://api.github.com/repos/skutylev/aws-devops',
'https://api.github.com/repos/tahaderouiche/ansibledockerjenkins',
'https://api.github.com/repos/Delvison/deploy_sensu',
'https://api.github.com/repos/putrasattvika/ossdev-assignment-v-playbook',
'https://api.github.com/repos/lfzamora81/ansible-playbooks',
'https://api.github.com/repos/wikitops/ansible_mariadb',
'https://api.github.com/repos/linben/dcos-local-gen',
'https://api.github.com/repos/florinen/apache_webserver',
'https://api.github.com/repos/wikitops/ansible_snort',
'https://api.github.com/repos/quanvuminh/kubesible',
'https://api.github.com/repos/wikitops/ansible_portus',
'https://api.github.com/repos/dimaskiddo/ansible-galera-org',
'https://api.github.com/repos/antrusd/ansible-hpilo-esxi-playbooks',
'https://api.github.com/repos/wikitops/ansible_jaeger',
'https://api.github.com/repos/ToolboxBodensee/ansible_deploy_tdott_displays',
'https://api.github.com/repos/illallangi-kubernetes/solid-giggle',
'https://api.github.com/repos/vgrosdoy/cisco-aci',
'https://api.github.com/repos/calshankar/Ansible-EC2-NginxDeploy',
'https://api.github.com/repos/heruscoder/ansible-ecs-deploy-playbook',
'https://api.github.com/repos/sjdillon/couchbase_backup_bucket',
'https://api.github.com/repos/dggreenbaum/ansible-swarm',
'https://api.github.com/repos/tjnh05/ambari',
'https://api.github.com/repos/wikitops/ansible_solr',
'https://api.github.com/repos/mclerix/openshift-tasks-apb',
'https://api.github.com/repos/jangosto/ansible-docker',
'https://api.github.com/repos/jessebarto/ansible-server-setup-deploy',
'https://api.github.com/repos/adasilva70/ansible-portworx',
'https://api.github.com/repos/jgrowl/ansible-playbook-common',
'https://api.github.com/repos/rcutmore/robcutmore.com-setup',
'https://api.github.com/repos/shanel262/AnsibleFYP',
'https://api.github.com/repos/garelp/wordpress-ubuntu-ha',
'https://api.github.com/repos/mickgortenmulder/ansible-powerdns',
'https://api.github.com/repos/clgch/ansible-slurm',
'https://api.github.com/repos/johndturn/ansible-playbook-jenkins',
'https://api.github.com/repos/feng-zh/aws-deploy',
'https://api.github.com/repos/tsew/kubernetes',
'https://api.github.com/repos/wikitops/ansible_voting',
'https://api.github.com/repos/wikitops/ansible_harbor',
'https://api.github.com/repos/ngstigator/deploy_authorized_keys',
'https://api.github.com/repos/wikitops/ansible_grafana',
'https://api.github.com/repos/sumitch787/Ansible',
'https://api.github.com/repos/makentenza/gluster-ocp',
'https://api.github.com/repos/OscarLopezEns/citoengine-ansible',
'https://api.github.com/repos/laardee/__outdated_serverless-deployment-ansible',
'https://api.github.com/repos/goozbach/mac-setup',
'https://api.github.com/repos/jefg60/ansible-master',
'https://api.github.com/repos/deng47/ansible-for-flask-api-server',
'https://api.github.com/repos/wikitops/ansible_epel',
'https://api.github.com/repos/Knytz/mks-playbooks',
'https://api.github.com/repos/oatakan/jboss-ansible-example',
'https://api.github.com/repos/yossisht9876/Ansible-Docker-ELK-Nginx',
'https://api.github.com/repos/wikitops/ansible_mongodb',
'https://api.github.com/repos/rebooting/playbook_setup_osx_aws_container_deployment',
'https://api.github.com/repos/project-oblivion/ceph-ansible',
'https://api.github.com/repos/bocharsky-bw/ansible-symfony-deploy',
'https://api.github.com/repos/skutylev/aws-devops',
'https://api.github.com/repos/tahaderouiche/ansibledockerjenkins',
'https://api.github.com/repos/Delvison/deploy_sensu',
'https://api.github.com/repos/putrasattvika/ossdev-assignment-v-playbook',
'https://api.github.com/repos/lfzamora81/ansible-playbooks',
'https://api.github.com/repos/wikitops/ansible_mariadb',
'https://api.github.com/repos/linben/dcos-local-gen',
'https://api.github.com/repos/florinen/apache_webserver',
'https://api.github.com/repos/wikitops/ansible_snort',
'https://api.github.com/repos/quanvuminh/kubesible',
'https://api.github.com/repos/wikitops/ansible_portus',
'https://api.github.com/repos/dimaskiddo/ansible-galera-org',
'https://api.github.com/repos/antrusd/ansible-hpilo-esxi-playbooks',
'https://api.github.com/repos/wikitops/ansible_jaeger',
'https://api.github.com/repos/ToolboxBodensee/ansible_deploy_tdott_displays',
'https://api.github.com/repos/illallangi-kubernetes/solid-giggle',
'https://api.github.com/repos/vgrosdoy/cisco-aci',
'https://api.github.com/repos/flyer8/exness',
'https://api.github.com/repos/natm/personalhosting-ansible',
'https://api.github.com/repos/OscarLopezEns/citoengine-full-ansible',
'https://api.github.com/repos/jgrowl/ansible-playbook-auth-client',
'https://api.github.com/repos/clouderasecurity/ansible',
'https://api.github.com/repos/Ensembl/resttng_deploy',
'https://api.github.com/repos/dhatanian/ansible-tomcat-grails',
'https://api.github.com/repos/wikitops/ansible_vault',
'https://api.github.com/repos/calshankar/Ansible-EC2-NginxDeploy',
'https://api.github.com/repos/heruscoder/ansible-ecs-deploy-playbook',
'https://api.github.com/repos/sjdillon/couchbase_backup_bucket',
'https://api.github.com/repos/dggreenbaum/ansible-swarm',
'https://api.github.com/repos/tjnh05/ambari',
'https://api.github.com/repos/wikitops/ansible_solr',
'https://api.github.com/repos/mclerix/openshift-tasks-apb',
'https://api.github.com/repos/jangosto/ansible-docker',
'https://api.github.com/repos/jessebarto/ansible-server-setup-deploy',
'https://api.github.com/repos/adasilva70/ansible-portworx',
'https://api.github.com/repos/crimsongreen/glusterfs',
'https://api.github.com/repos/dmilind/Ansible',
'https://api.github.com/repos/cbanciu667/cos_ansible_jenkins',
'https://api.github.com/repos/open-io/ansible-playbook-deployment-elkf',
'https://api.github.com/repos/AiAlex/playbooks',
'https://api.github.com/repos/wikitops/ansible_nginx',
'https://api.github.com/repos/wikitops/ansible_locust',
'https://api.github.com/repos/wikitops/ansible_wildfly',
'https://api.github.com/repos/eysdo/ansible',
'https://api.github.com/repos/wikitops/ansible_ruby',
'https://api.github.com/repos/tombosmansibm/isam_playbooks_public',
'https://api.github.com/repos/InformaticsMatters/squonk-ansible',
'https://api.github.com/repos/goozbach/mac-setup',
'https://api.github.com/repos/OscarLopezEns/citoengine-ansible',
'https://api.github.com/repos/laardee/__outdated_serverless-deployment-ansible',
'https://api.github.com/repos/rebooting/playbook_setup_osx_aws_container_deployment',
'https://api.github.com/repos/yossisht9876/Ansible-Docker-ELK-Nginx',
'https://api.github.com/repos/dparrish-mesosphere/dcos-ansible',
'https://api.github.com/repos/r3lik/ansible-vagrant-kubeadm',
'https://api.github.com/repos/wasanthag/ansible_deploy_sensu_ha',
'https://api.github.com/repos/nwiizo/kubernetes-on-conohas',
'https://api.github.com/repos/aish77/Ansible-Deploy-On-Tomcat',
'https://api.github.com/repos/Syamlal-M/ansible-deploying-ec2',
'https://api.github.com/repos/ten0s/alley-ansible',
'https://api.github.com/repos/osbuild/ansible-osbuild',
'https://api.github.com/repos/goozbach/mac-setup',
'https://api.github.com/repos/OscarLopezEns/citoengine-ansible',
'https://api.github.com/repos/laardee/__outdated_serverless-deployment-ansible',
'https://api.github.com/repos/rebooting/playbook_setup_osx_aws_container_deployment',
'https://api.github.com/repos/yossisht9876/Ansible-Docker-ELK-Nginx',
'https://api.github.com/repos/deng47/ansible-for-flask-api-server',
'https://api.github.com/repos/Knytz/mks-playbooks',
'https://api.github.com/repos/wikitops/ansible_mongodb',
'https://api.github.com/repos/makentenza/gluster-ocp',
'https://api.github.com/repos/wikitops/ansible_epel',
'https://api.github.com/repos/oatakan/jboss-ansible-example',
'https://api.github.com/repos/project-oblivion/ceph-ansible',
'https://api.github.com/repos/jefg60/ansible-master',
'https://api.github.com/repos/8341app/deploy',
'https://api.github.com/repos/chapter09/iperf-cron',
'https://api.github.com/repos/coolpalani/ansible-filebeat',
'https://api.github.com/repos/sharoukhAkbar/ANSIBLE_JAVA_DEPLOYMENT',
'https://api.github.com/repos/CASecuritySWAT/ansible-ca-sso',
'https://api.github.com/repos/wikitops/ansible_rabbitmq',
'https://api.github.com/repos/trumland/Deploy_NSX-T_ANSIBLE',
'https://api.github.com/repos/fdeh75/ansible_gitea_docker',
'https://api.github.com/repos/wikitops/ansible_filebeat']

# %%
final_list = list(map(lambda x: x.replace('https://api.github.com/repos/', ''),result_list))

# %%
print(len(final_list))
unique_repos_ansible = list(set(final_list))
print(len(unique_repos_ansible))
# Out:
# 870
# 774
